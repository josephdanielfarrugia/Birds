# %% [markdown]
# ### Parse Data and save it in Dictionary sList

# %%
def retrievemonths():
    months = [] 

    with open("./data/Honeymoon Island.txt", 'r') as f:
        (f.readline())  
   # print(lines)
    # burn the header row
        txt_text =""
        for line in f.readlines()[1:15:]: 
      #  print(line)
            tokens = line.strip().split('\t')   # tokenize the row based on spaces
       
            if (len(tokens) < 15):
                continue
            
       ###  parsing file
            birdname= tokens[0]
            s1 = tokens[1]
            s2 = tokens[2]
            s3 = tokens[3]
            s4 = tokens[4]
            s5 = tokens[5]
            s6 = tokens[6]
            s7 = tokens[7]
            s8 = tokens[8]
            s9 = tokens[9]
            s10= tokens[10]
            s11 = tokens[11]
            s12 = tokens[12]
        
            s13 = tokens[13]
            s14 = tokens[14]
  
            months.append(birdname)
            months.append(s4)
            months.append(s8)
            months.append(s12)
        
            samplelist= []
            samplelist.append(s1)
            samplelist.append(s2)
            samplelist.append(s3)
            samplelist.append(s4)
            samplelist.append(s5)
            samplelist.append(s6)
            samplelist.append(s7)
            samplelist.append(s8)
            samplelist.append(s9)
            samplelist.append(s10)
            samplelist.append(s11)
            samplelist.append(s12)
            samplelist.append(s13)
            samplelist.append(s14)
    f.close()    
    months.pop()
    months.pop()
    months.pop()
    months.pop()
    return months, samplelist
retrievemonths();

# %%
def parsedata():
    s={}
    slist = [] 
    listahadra = [] 
    with open("./data/Honeymoon Island.txt", 'r') as f:
        (f.readline())  
    
   # print(lines)
    # burn the header row
        txt_text =""
        for line in f.readlines()[15:]:
       
           # print(line)
            tokens = line.strip().split('\t')   # tokenize the row based on spaces
       
            if (len(tokens) < 15):
                continue
        
       ###  parsing file
            birdname= tokens[0]
            
            s1 = tokens[1]
            s2 = tokens[2]
            s3 = tokens[3]
            s4 = tokens[4]
            s5 = tokens[5]
            s6 = tokens[6]
            s7 = tokens[7]
            s8 = tokens[8]
            s9 = tokens[9]
            s10= tokens[10]
            s11 = tokens[11]
            s12 = tokens[12]
        
            s13 = tokens[13]
            s14 = tokens[14]
        
           
            s ={}
      
            s["birdname"] = birdname
            s["s1"] =s1
            s["s2"] = s2
            s["s3"] = s3
            s["s4"] = s4
            s["s5"] = s5
            s["s6"] =s6
            s["s7"] = s7
      #  s["img"] = imgname
      #  print(filename, client, content_type, slide_number,text)
            s["s8"] = s8
            s["s9"] = s9
            s["s10"] = s10
            s["s11"] = s11
            s["s12"] = s12
            s["s13"] = s13
            s["s14"] = s14
        
            if (len(s) > 0):
                slist.append(s)
            
    return slist
parsedata()[:13];

# %%
parsedata()[0];

# %%
def createlist():
    mylist=[]
    file = "Honeymoon Island"
    #month =slist[0]["birdname"]
    months = retrievemonths()
    a ,samplelist = retrievemonths()
    week = 1

    slist =(parsedata()[0:13])
    printlist =(parsedata()[0:13])

    for j in range(0,13):
        if j == 0:
            mylist= []
            for i in range(0,len(printlist)):
                value = slist[i]["s1"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('1')
                mylist.append(samplelist[0])
                mylist.append('2021')
                mylist.append(value)
        if j == 1:
            for i in range(0,len(printlist)):
                value = slist[i]["s2"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('2')
                mylist.append(samplelist[1])
                mylist.append('2021')
                mylist.append(value)
        if j == 2:
            for i in range(0,len(printlist)):
                value = slist[i]["s3"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('3')
                mylist.append(samplelist[2])
                mylist.append('2021')
                mylist.append(value)
        if j == 3:
            for i in range(0,len(printlist)):
                value = slist[i]["s4"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('4')
                mylist.append(samplelist[3])
                mylist.append('2021')
                mylist.append(value)
        if j == 4:
            for i in range(0,len(printlist)):
                value = slist[i]["s5"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('5')
                mylist.append(samplelist[4])
                mylist.append('2021')
                mylist.append(value)
        if j == 5:
            for i in range(0,len(printlist)):
                value = slist[i]["s6"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('6')
                mylist.append(samplelist[5])
                mylist.append('2021')
                mylist.append(value)
        if j == 6:
            for i in range(0,len(printlist)):
                value = slist[i]["s7"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('7')
                mylist.append(samplelist[6])
                mylist.append('2021')
                mylist.append(value)
        if j == 7:
            for i in range(0,len(printlist)):
                value = slist[i]["s8"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('8')
                mylist.append(samplelist[7])
                mylist.append('2021')
                mylist.append(value)
        if j == 8:
            for i in range(0,len(printlist)):
                value = slist[i]["s9"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('9')
                mylist.append(samplelist[8])
                mylist.append('2021')
                mylist.append(value)
        if j == 9:
            for i in range(0,len(printlist)):
                value = slist[i]["s10"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('10')
                mylist.append(samplelist[9])
                mylist.append('2021')
                mylist.append(value)
        if j == 10:
            for i in range(0,len(printlist)):
                value = slist[i]["s11"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('11')
                mylist.append(samplelist[10])
                mylist.append('2021')
                mylist.append(value)
        if j == 11:
            for i in range(0,len(printlist)):
                value = slist[i]["s12"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('12')
                mylist.append(samplelist[11])
                mylist.append('2021')
                mylist.append(value)
        if j == 12:
            for i in range(0,len(printlist)):
                value = slist[i]["s13"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('13')
                mylist.append(samplelist[12])
                mylist.append('2021')
                mylist.append(value)
        if j == 13:
            for i in range(0,len(printlist)):
                value = slist[i]["s14"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('14')
                mylist.append(samplelist[13])
                mylist.append('2021')
                mylist.append(value)
    return mylist
a = createlist()
a;

# %%
import json
with open('birds.txt', 'w') as filehandle:
    json.dump(createlist(), filehandle)

# %%
a ,samplelist = retrievemonths()
samplelist[0]
# Out:
# '10.0'

# %%
import sqlite3

def create_table():
    #Connecting to sqlite
    conn = sqlite3.connect('./data/bird_lupu.db')


    #Creating a cursor object using the cursor() method
    cursor = conn.cursor()

    #Droping BIRDS table if already exists.
    #cursor.execute("DROP TABLE IF EXISTS Birds")

    #Creating table as per requirement
    sql=''' CREATE TABLE IF NOT EXISTS Birds 
        (id integer PRIMARY KEY NOT NULL ,
         Location text NOT NULL, 
         BirdName text NOT NULL,
         Month text NOT NULL, 
         Week integer not null, 
         Sample real not null, 
         Year integer NOT NULL, 
         Value real NOT null)'''
    cursor.execute(sql)
    print("Table created successfully........")

    # Commit your changes in the database
    conn.commit()

    #Closing the connection
    conn.close()
create_table()
# Out:
# Table created successfully........

# %%
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    conn = sqlite3.connect('bird.db')
    cur = conn.cursor()
    cur.execute("SELECT * FROM Birds")

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
select_all_tasks(conn)
# Out:
# (1, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 1, 10, 2021, 0.1)
# (2, 'Black-bellied Whistling-Duck', 'Jan', '1', 10, 2021, 0.1, 'Honeymoon Island')
# (3, 'Jan', '1', '10.0', 2021, 0.1, 'Honeymoon Island', 'Blue-winged Teal')
# (4, '1', '10.0', '2021', 0.1, 'Honeymoon Island', 'Blue-winged Teal', 'Jan')
# (5, '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1)
# (6, '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10)
# (7, '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10, 2021)
# (8, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10, 2021, 0.2)
# (9, 'Blue-winged Teal', 'Jan', '1', 10, 2021, 0.2, 'Honeymoon Island')
# (10, 'Jan', '1', '10.0', 2021, 0.2, 'Honeymoon Island', 'Redhead')
# (11, '1', '10.0', '2021', 0.2, 'Honeymoon Island', 'Redhead', 'Jan')
# (12, '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', 1)
# (13, '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', 1, 10)

# %% [markdown]
# # SQL NOT ENTERED CORRECTLY IN DATABASE

# %%
def create_task():
    """
    Create a new task
    :param conn:
    :param task:
    :return:
    """
  
    conn = sqlite3.connect(r"./data/bird.db")
    cur = conn.cursor()
    
    for i in range((len(createlist()[:13]))):
        task = (createlist()[i:][0], createlist()[i:][1], createlist()[i:][2], createlist()[i:][3], createlist()[i:][4], createlist()[i:][5],createlist()[i:][6])
       # task = createlist()[i:][0]
        sql = ''' INSERT INTO BIRDS(Location, BirdName, Month,Week,Sample, Year, Value) VALUES(?,?,?,?,?,?,?)'''  
        cur = conn.cursor()
        cur.execute(sql,task)
        print(task)
        conn.commit()
    return cur.lastrowid
    #return sql

#for i in range(len(createlist())-7):
 #   task_1 = (createlist()[i:][0], createlist()[i:][1], createlist()[i:][2], createlist()[i:][3], createlist()[i:][4], createlist()[i:][5],createlist()[i:][6])
   # print(task_1)
create_task()
# Out:
# ('Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', '1', '10.0', '2021', '0.1')
# ('Black-bellied Whistling-Duck', 'Jan', '1', '10.0', '2021', '0.1', 'Honeymoon Island')
# ('Jan', '1', '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal')
# ('1', '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan')
# ('10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1')
# ('2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0')
# ('0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0', '2021')
# ('Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0', '2021', '0.2')
# ('Blue-winged Teal', 'Jan', '1', '10.0', '2021', '0.2', 'Honeymoon Island')
# ('Jan', '1', '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead')
# ('1', '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan')
# ('10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', '1')
# ('2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', '1', '10.0')
# 13

# %% [markdown]
# # THIS SHOULD BE THE SAME AS WRITTEN IN DB!!!

# %%
createlist()
# Out:
# ['Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.2',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.3',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.4',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.7',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.6',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.4',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '2.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '2.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '3.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.2',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '1.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.6',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Jan',
#  '2',
#  '5.0',
#  '2021',
#  '0.2',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '3.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0833333',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0833333',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.1666667',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0833333',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0833333',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.0833333',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.8333333',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.75',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Jan',
#  '3',
#  '12.0',
#  '2021',
#  '0.4166667',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '4.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.1818182',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.6363636',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.5454545',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Jan',
#  '4',
#  '11.0',
#  '2021',
#  '0.3636364',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '5.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Redhead',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0909091',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.5454545',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.6363636',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Feb',
#  '5',
#  '11.0',
#  '2021',
#  '0.4545455',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '6.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Feb',
#  '6',
#  '-1.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '7.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Feb',
#  '7',
#  '-2.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '8.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Feb',
#  '8',
#  '-3.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '9.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Feb',
#  '9',
#  '-4.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '10.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Mar',
#  '10',
#  '-5.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '11.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Common Ground Dove',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Mourning Dove',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'American Oystercatcher',
#  'Mar',
#  '11',
#  '-6.0',
#  '2021',
#  ...]

# %% [markdown]
# # LUPU'S VERSION

# %%
all_tokens = []
with open("./data/Honeymoon Island.txt", 'r') as f:
    for line in f.readlines():
        tokens = line.strip().split('\t')   # tokenize the row based on spaces
        all_tokens.append(tokens)

# %%
MONTH_INDEX = 13
SAMPLE_INDEX = 14
BIRD_START_INDEX = 16
location = "Honeymoon Island" # you have to get this from the file

# %%
#
'''
Create filled in month list. 
The original month list is like this ['Jan', '', '', '', 'Feb', '', '' ...]
I'm creating a month list that fills in the gaps so that then we can use it in the output like this 
    ['Jan', 'Jan', 'Jan', 'Jan', 'Feb', Feb', 'Feb' ...]
'''
month_list = []
for m in all_tokens[MONTH_INDEX]:
    if m == "":
        month_list.append(prior_month)
    else:
        month_list.append(m)
        prior_month = m

# %%
records = [(1, 'Glen', 8),
			(2, 'Elliot', 9),
			(3, 'Bob', 7)]

#insert multiple records in a single query
c.executemany('INSERT INTO students VALUES(?,?,?);',records);

# %%
db_records = []
for bird_index in range(BIRD_START_INDEX, len(all_tokens)-1):
    bird_data = all_tokens[bird_index]
    for bird_record_index in range(1, len(bird_data)):
        if bird_record_index < len(month_list):
            #print (location, bird_data[0], month_list[bird_record_index-1], bird_record_index, all_tokens[SAMPLE_INDEX][bird_record_index], "2021", bird_data[bird_record_index])
            db_records.append ((location, bird_data[0], month_list[bird_record_index-1], bird_record_index, all_tokens[SAMPLE_INDEX][bird_record_index], "2021", bird_data[bird_record_index]))

# %%
# Same thing to insert in DB
conn = sqlite3.connect(r"./data/bird_lupu.db")
sql = ''' INSERT INTO Birds (Location, BirdName, Month,Week,Sample, Year, Value) VALUES(?,?,?,?,?,?,?)'''  
cur = conn.cursor()
cur.executemany(sql,db_records)
conn.commit()

# %%
def select_all_tasks():
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    conn = sqlite3.connect('./data/bird_lupu.db')
    cur = conn.cursor()
    cur.execute("SELECT * FROM Birds")

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
select_all_tasks()
# Out:
# (1, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 1, 10.0, 2021, 0.1)
# (2, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 2, 5.0, 2021, 1.0)
# (3, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 3, 12.0, 2021, 0.0)
# (4, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 4, 11.0, 2021, 0.0)
# (5, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Feb', 5, 11.0, 2021, 0.0)
# (6, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Feb', 6, 0.0, 2021, 0.0)
# (7, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Feb', 7, 0.0, 2021, 0.0)
# (8, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Feb', 8, 0.0, 2021, 0.0)
# (9, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Mar', 9, 0.0, 2021, 0.0)
# (10, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Mar', 10, 0.0, 2021, 0.0)
# (11, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Mar', 11, 0.0, 2021, 0.0)
# (12, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Mar', 12, 0.0, 2021, 0.0)
# (13, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Apr', 13, 0.0, 2021, 0.0)
# (14, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Apr', 14, 0.0, 2021, 0.0)
# (15, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Apr', 15, 0.0, 2021, 0.0)
# (16, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Apr', 16, 0.0, 2021, 0.0)
# (17, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'May', 17, 0.0, 2021, 0.0)
# (18, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'May', 18, 0.0, 2021, 0.0)
# (19, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'May', 19, 0.0, 2021, 0.0)
# (20, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'May', 20, 0.0, 2021, 0.0)
# (21, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jun', 21, 0.0, 2021, 0.0)
# (22, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jun', 22, 0.0, 2021, 0.0)
# (23, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jun', 23, 0.0, 2021, 0.0)
# (24, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jun', 24, 0.0, 2021, 0.0)
# (25, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jul', 25, 0.0, 2021, 0.0)
# (26, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jul', 26, 0.0, 2021, 0.0)
# (27, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jul', 27, 0.0, 2021, 0.0)
# (28, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jul', 28, 0.0, 2021, 0.0)
# (29, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Aug', 29, 0.0, 2021, 0.0)
# (30, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Aug', 30, 0.0, 2021, 0.0)
# (31, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Aug', 31, 0.0, 2021, 0.0)
# (32, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Aug', 32, 0.0, 2021, 0.0)
# (33, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Sep', 33, 0.0, 2021, 0.0)
# (34, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Sep', 34, 0.0, 2021, 0.0)
# (35, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Sep', 35, 0.0, 2021, 0.0)
# (36, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Sep', 36, 0.0, 2021, 0.0)
# (37, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Oct', 37, 0.0, 2021, 0.0)
# (38, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Oct', 38, 0.0, 2021, 0.0)
# (39, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Oct', 39, 0.0, 2021, 0.0)
# (40, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Oct', 40, 0.0, 2021, 0.0)
# (41, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Nov', 41, 0.0, 2021, 0.0)
# (42, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Nov', 42, 0.0, 2021, 0.0)
# (43, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Nov', 43, 0.0, 2021, 0.0)
# (44, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Nov', 44, 0.0, 2021, 0.0)
# (45, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10.0, 2021, 0.2)
# (46, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 2, 5.0, 2021, 2.0)
# (47, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 3, 12.0, 2021, 0.0)
# (48, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 4, 11.0, 2021, 0.0)
# (49, 'Honeymoon Island', 'Blue-winged Teal', 'Feb', 5, 11.0, 2021, 0.0909091)
# (50, 'Honeymoon Island', 'Blue-winged Teal', 'Feb', 6, 0.0, 2021, 0.0)
# (51, 'Honeymoon Island', 'Blue-winged Teal', 'Feb', 7, 0.0, 2021, 0.0)
# (52, 'Honeymoon Island', 'Blue-winged Teal', 'Feb', 8, 0.0, 2021, 0.0)
# (53, 'Honeymoon Island', 'Blue-winged Teal', 'Mar', 9, 0.0, 2021, 0.0)
# (54, 'Honeymoon Island', 'Blue-winged Teal', 'Mar', 10, 0.0, 2021, 0.0)
# (55, 'Honeymoon Island', 'Blue-winged Teal', 'Mar', 11, 0.0, 2021, 0.0)
# (56, 'Honeymoon Island', 'Blue-winged Teal', 'Mar', 12, 0.0, 2021, 0.0)
# (57, 'Honeymoon Island', 'Blue-winged Teal', 'Apr', 13, 0.0, 2021, 0.0)
# (58, 'Honeymoon Island', 'Blue-winged Teal', 'Apr', 14, 0.0, 2021, 0.0)
# (59, 'Honeymoon Island', 'Blue-winged Teal', 'Apr', 15, 0.0, 2021, 0.0)
# (60, 'Honeymoon Island', 'Blue-winged Teal', 'Apr', 16, 0.0, 2021, 0.0)
# (61, 'Honeymoon Island', 'Blue-winged Teal', 'May', 17, 0.0, 2021, 0.0)
# (62, 'Honeymoon Island', 'Blue-winged Teal', 'May', 18, 0.0, 2021, 0.0)
# (63, 'Honeymoon Island', 'Blue-winged Teal', 'May', 19, 0.0, 2021, 0.0)
# (64, 'Honeymoon Island', 'Blue-winged Teal', 'May', 20, 0.0, 2021, 0.0)
# (65, 'Honeymoon Island', 'Blue-winged Teal', 'Jun', 21, 0.0, 2021, 0.0)
# (66, 'Honeymoon Island', 'Blue-winged Teal', 'Jun', 22, 0.0, 2021, 0.0)
# (67, 'Honeymoon Island', 'Blue-winged Teal', 'Jun', 23, 0.0, 2021, 0.0)
# (68, 'Honeymoon Island', 'Blue-winged Teal', 'Jun', 24, 0.0, 2021, 0.0)
# (69, 'Honeymoon Island', 'Blue-winged Teal', 'Jul', 25, 0.0, 2021, 0.0)
# (70, 'Honeymoon Island', 'Blue-winged Teal', 'Jul', 26, 0.0, 2021, 0.0)
# (71, 'Honeymoon Island', 'Blue-winged Teal', 'Jul', 27, 0.0, 2021, 0.0)
# (72, 'Honeymoon Island', 'Blue-winged Teal', 'Jul', 28, 0.0, 2021, 0.0)
# (73, 'Honeymoon Island', 'Blue-winged Teal', 'Aug', 29, 0.0, 2021, 0.0)
# (74, 'Honeymoon Island', 'Blue-winged Teal', 'Aug', 30, 0.0, 2021, 0.0)
# (75, 'Honeymoon Island', 'Blue-winged Teal', 'Aug', 31, 0.0, 2021, 0.0)
# (76, 'Honeymoon Island', 'Blue-winged Teal', 'Aug', 32, 0.0, 2021, 0.0)
# (77, 'Honeymoon Island', 'Blue-winged Teal', 'Sep', 33, 0.0, 2021, 0.0)
# (78, 'Honeymoon Island', 'Blue-winged Teal', 'Sep', 34, 0.0, 2021, 0.0)
# (79, 'Honeymoon Island', 'Blue-winged Teal', 'Sep', 35, 0.0, 2021, 0.0)
# (80, 'Honeymoon Island', 'Blue-winged Teal', 'Sep', 36, 0.0, 2021, 0.0)
# (81, 'Honeymoon Island', 'Blue-winged Teal', 'Oct', 37, 0.0, 2021, 0.0)
# (82, 'Honeymoon Island', 'Blue-winged Teal', 'Oct', 38, 0.0, 2021, 0.0)
# (83, 'Honeymoon Island', 'Blue-winged Teal', 'Oct', 39, 0.0, 2021, 0.0)
# (84, 'Honeymoon Island', 'Blue-winged Teal', 'Oct', 40, 0.0, 2021, 0.0)
# (85, 'Honeymoon Island', 'Blue-winged Teal', 'Nov', 41, 0.0, 2021, 0.0)
# (86, 'Honeymoon Island', 'Blue-winged Teal', 'Nov', 42, 0.0, 2021, 0.0)
# (87, 'Honeymoon Island', 'Blue-winged Teal', 'Nov', 43, 0.0, 2021, 0.0)
# (88, 'Honeymoon Island', 'Blue-winged Teal', 'Nov', 44, 0.0, 2021, 0.0)
# (89, 'Honeymoon Island', 'Redhead', 'Jan', 1, 10.0, 2021, 0.3)
# (90, 'Honeymoon Island', 'Redhead', 'Jan', 2, 5.0, 2021, 3.0)
# (91, 'Honeymoon Island', 'Redhead', 'Jan', 3, 12.0, 2021, 0.0)
# (92, 'Honeymoon Island', 'Redhead', 'Jan', 4, 11.0, 2021, 0.0909091)
# (93, 'Honeymoon Island', 'Redhead', 'Feb', 5, 11.0, 2021, 0.0909091)
# (94, 'Honeymoon Island', 'Redhead', 'Feb', 6, 0.0, 2021, 0.0)
# (95, 'Honeymoon Island', 'Redhead', 'Feb', 7, 0.0, 2021, 0.0)
# (96, 'Honeymoon Island', 'Redhead', 'Feb', 8, 0.0, 2021, 0.0)
# (97, 'Honeymoon Island', 'Redhead', 'Mar', 9, 0.0, 2021, 0.0)
# (98, 'Honeymoon Island', 'Redhead', 'Mar', 10, 0.0, 2021, 0.0)
# (99, 'Honeymoon Island', 'Redhead', 'Mar', 11, 0.0, 2021, 0.0)
# (100, 'Honeymoon Island', 'Redhead', 'Mar', 12, 0.0, 2021, 0.0)
# (101, 'Honeymoon Island', 'Redhead', 'Apr', 13, 0.0, 2021, 0.0)
# (102, 'Honeymoon Island', 'Redhead', 'Apr', 14, 0.0, 2021, 0.0)
# (103, 'Honeymoon Island', 'Redhead', 'Apr', 15, 0.0, 2021, 0.0)
# (104, 'Honeymoon Island', 'Redhead', 'Apr', 16, 0.0, 2021, 0.0)
# (105, 'Honeymoon Island', 'Redhead', 'May', 17, 0.0, 2021, 0.0)
# (106, 'Honeymoon Island', 'Redhead', 'May', 18, 0.0, 2021, 0.0)
# (107, 'Honeymoon Island', 'Redhead', 'May', 19, 0.0, 2021, 0.0)
# (108, 'Honeymoon Island', 'Redhead', 'May', 20, 0.0, 2021, 0.0)
# (109, 'Honeymoon Island', 'Redhead', 'Jun', 21, 0.0, 2021, 0.0)
# (110, 'Honeymoon Island', 'Redhead', 'Jun', 22, 0.0, 2021, 0.0)
# (111, 'Honeymoon Island', 'Redhead', 'Jun', 23, 0.0, 2021, 0.0)
# (112, 'Honeymoon Island', 'Redhead', 'Jun', 24, 0.0, 2021, 0.0)
# (113, 'Honeymoon Island', 'Redhead', 'Jul', 25, 0.0, 2021, 0.0)
# (114, 'Honeymoon Island', 'Redhead', 'Jul', 26, 0.0, 2021, 0.0)
# (115, 'Honeymoon Island', 'Redhead', 'Jul', 27, 0.0, 2021, 0.0)
# (116, 'Honeymoon Island', 'Redhead', 'Jul', 28, 0.0, 2021, 0.0)
# (117, 'Honeymoon Island', 'Redhead', 'Aug', 29, 0.0, 2021, 0.0)
# (118, 'Honeymoon Island', 'Redhead', 'Aug', 30, 0.0, 2021, 0.0)
# (119, 'Honeymoon Island', 'Redhead', 'Aug', 31, 0.0, 2021, 0.0)
# (120, 'Honeymoon Island', 'Redhead', 'Aug', 32, 0.0, 2021, 0.0)
# (121, 'Honeymoon Island', 'Redhead', 'Sep', 33, 0.0, 2021, 0.0)
# (122, 'Honeymoon Island', 'Redhead', 'Sep', 34, 0.0, 2021, 0.0)
# (123, 'Honeymoon Island', 'Redhead', 'Sep', 35, 0.0, 2021, 0.0)
# (124, 'Honeymoon Island', 'Redhead', 'Sep', 36, 0.0, 2021, 0.0)
# (125, 'Honeymoon Island', 'Redhead', 'Oct', 37, 0.0, 2021, 0.0)
# (126, 'Honeymoon Island', 'Redhead', 'Oct', 38, 0.0, 2021, 0.0)
# (127, 'Honeymoon Island', 'Redhead', 'Oct', 39, 0.0, 2021, 0.0)
# (128, 'Honeymoon Island', 'Redhead', 'Oct', 40, 0.0, 2021, 0.0)
# (129, 'Honeymoon Island', 'Redhead', 'Nov', 41, 0.0, 2021, 0.0)
# (130, 'Honeymoon Island', 'Redhead', 'Nov', 42, 0.0, 2021, 0.0)
# (131, 'Honeymoon Island', 'Redhead', 'Nov', 43, 0.0, 2021, 0.0)
# (132, 'Honeymoon Island', 'Redhead', 'Nov', 44, 0.0, 2021, 0.0)
# (133, 'Honeymoon Island', 'Lesser Scaup', 'Jan', 1, 10.0, 2021, 0.0)
# (134, 'Honeymoon Island', 'Lesser Scaup', 'Jan', 2, 5.0, 2021, 0.0)
# (135, 'Honeymoon Island', 'Lesser Scaup', 'Jan', 3, 12.0, 2021, 0.0833333)
# (136, 'Honeymoon Island', 'Lesser Scaup', 'Jan', 4, 11.0, 2021, 0.0909091)
# (137, 'Honeymoon Island', 'Lesser Scaup', 'Feb', 5, 11.0, 2021, 0.0)
# (138, 'Honeymoon Island', 'Lesser Scaup', 'Feb', 6, 0.0, 2021, 0.0)
# (139, 'Honeymoon Island', 'Lesser Scaup', 'Feb', 7, 0.0, 2021, 0.0)
# (140, 'Honeymoon Island', 'Lesser Scaup', 'Feb', 8, 0.0, 2021, 0.0)
# (141, 'Honeymoon Island', 'Lesser Scaup', 'Mar', 9, 0.0, 2021, 0.0)
# (142, 'Honeymoon Island', 'Lesser Scaup', 'Mar', 10, 0.0, 2021, 0.0)
# (143, 'Honeymoon Island', 'Lesser Scaup', 'Mar', 11, 0.0, 2021, 0.0)
# (144, 'Honeymoon Island', 'Lesser Scaup', 'Mar', 12, 0.0, 2021, 0.0)
# (145, 'Honeymoon Island', 'Lesser Scaup', 'Apr', 13, 0.0, 2021, 0.0)
# (146, 'Honeymoon Island', 'Lesser Scaup', 'Apr', 14, 0.0, 2021, 0.0)
# (147, 'Honeymoon Island', 'Lesser Scaup', 'Apr', 15, 0.0, 2021, 0.0)
# (148, 'Honeymoon Island', 'Lesser Scaup', 'Apr', 16, 0.0, 2021, 0.0)
# (149, 'Honeymoon Island', 'Lesser Scaup', 'May', 17, 0.0, 2021, 0.0)
# (150, 'Honeymoon Island', 'Lesser Scaup', 'May', 18, 0.0, 2021, 0.0)
# (151, 'Honeymoon Island', 'Lesser Scaup', 'May', 19, 0.0, 2021, 0.0)
# (152, 'Honeymoon Island', 'Lesser Scaup', 'May', 20, 0.0, 2021, 0.0)
# (153, 'Honeymoon Island', 'Lesser Scaup', 'Jun', 21, 0.0, 2021, 0.0)
# (154, 'Honeymoon Island', 'Lesser Scaup', 'Jun', 22, 0.0, 2021, 0.0)
# (155, 'Honeymoon Island', 'Lesser Scaup', 'Jun', 23, 0.0, 2021, 0.0)
# (156, 'Honeymoon Island', 'Lesser Scaup', 'Jun', 24, 0.0, 2021, 0.0)
# (157, 'Honeymoon Island', 'Lesser Scaup', 'Jul', 25, 0.0, 2021, 0.0)
# (158, 'Honeymoon Island', 'Lesser Scaup', 'Jul', 26, 0.0, 2021, 0.0)
# (159, 'Honeymoon Island', 'Lesser Scaup', 'Jul', 27, 0.0, 2021, 0.0)
# (160, 'Honeymoon Island', 'Lesser Scaup', 'Jul', 28, 0.0, 2021, 0.0)
# (161, 'Honeymoon Island', 'Lesser Scaup', 'Aug', 29, 0.0, 2021, 0.0)
# (162, 'Honeymoon Island', 'Lesser Scaup', 'Aug', 30, 0.0, 2021, 0.0)
# (163, 'Honeymoon Island', 'Lesser Scaup', 'Aug', 31, 0.0, 2021, 0.0)
# (164, 'Honeymoon Island', 'Lesser Scaup', 'Aug', 32, 0.0, 2021, 0.0)
# (165, 'Honeymoon Island', 'Lesser Scaup', 'Sep', 33, 0.0, 2021, 0.0)
# (166, 'Honeymoon Island', 'Lesser Scaup', 'Sep', 34, 0.0, 2021, 0.0)
# (167, 'Honeymoon Island', 'Lesser Scaup', 'Sep', 35, 0.0, 2021, 0.0)
# (168, 'Honeymoon Island', 'Lesser Scaup', 'Sep', 36, 0.0, 2021, 0.0)
# (169, 'Honeymoon Island', 'Lesser Scaup', 'Oct', 37, 0.0, 2021, 0.0)
# (170, 'Honeymoon Island', 'Lesser Scaup', 'Oct', 38, 0.0, 2021, 0.0)
# (171, 'Honeymoon Island', 'Lesser Scaup', 'Oct', 39, 0.0, 2021, 0.0)
# (172, 'Honeymoon Island', 'Lesser Scaup', 'Oct', 40, 0.0, 2021, 0.0)
# (173, 'Honeymoon Island', 'Lesser Scaup', 'Nov', 41, 0.0, 2021, 0.0)
# (174, 'Honeymoon Island', 'Lesser Scaup', 'Nov', 42, 0.0, 2021, 0.0)
# (175, 'Honeymoon Island', 'Lesser Scaup', 'Nov', 43, 0.0, 2021, 0.0)
# (176, 'Honeymoon Island', 'Lesser Scaup', 'Nov', 44, 0.0, 2021, 0.0)
# (177, 'Honeymoon Island', 'Bufflehead', 'Jan', 1, 10.0, 2021, 0.0)
# (178, 'Honeymoon Island', 'Bufflehead', 'Jan', 2, 5.0, 2021, 0.0)
# (179, 'Honeymoon Island', 'Bufflehead', 'Jan', 3, 12.0, 2021, 0.0833333)
# (180, 'Honeymoon Island', 'Bufflehead', 'Jan', 4, 11.0, 2021, 0.0)
# (181, 'Honeymoon Island', 'Bufflehead', 'Feb', 5, 11.0, 2021, 0.0)
# (182, 'Honeymoon Island', 'Bufflehead', 'Feb', 6, 0.0, 2021, 0.0)
# (183, 'Honeymoon Island', 'Bufflehead', 'Feb', 7, 0.0, 2021, 0.0)
# (184, 'Honeymoon Island', 'Bufflehead', 'Feb', 8, 0.0, 2021, 0.0)
# (185, 'Honeymoon Island', 'Bufflehead', 'Mar', 9, 0.0, 2021, 0.0)
# (186, 'Honeymoon Island', 'Bufflehead', 'Mar', 10, 0.0, 2021, 0.0)
# (187, 'Honeymoon Island', 'Bufflehead', 'Mar', 11, 0.0, 2021, 0.0)
# (188, 'Honeymoon Island', 'Bufflehead', 'Mar', 12, 0.0, 2021, 0.0)
# (189, 'Honeymoon Island', 'Bufflehead', 'Apr', 13, 0.0, 2021, 0.0)
# (190, 'Honeymoon Island', 'Bufflehead', 'Apr', 14, 0.0, 2021, 0.0)
# (191, 'Honeymoon Island', 'Bufflehead', 'Apr', 15, 0.0, 2021, 0.0)
# (192, 'Honeymoon Island', 'Bufflehead', 'Apr', 16, 0.0, 2021, 0.0)
# (193, 'Honeymoon Island', 'Bufflehead', 'May', 17, 0.0, 2021, 0.0)
# (194, 'Honeymoon Island', 'Bufflehead', 'May', 18, 0.0, 2021, 0.0)
# (195, 'Honeymoon Island', 'Bufflehead', 'May', 19, 0.0, 2021, 0.0)
# (196, 'Honeymoon Island', 'Bufflehead', 'May', 20, 0.0, 2021, 0.0)
# (197, 'Honeymoon Island', 'Bufflehead', 'Jun', 21, 0.0, 2021, 0.0)
# (198, 'Honeymoon Island', 'Bufflehead', 'Jun', 22, 0.0, 2021, 0.0)
# (199, 'Honeymoon Island', 'Bufflehead', 'Jun', 23, 0.0, 2021, 0.0)
# (200, 'Honeymoon Island', 'Bufflehead', 'Jun', 24, 0.0, 2021, 0.0)
# (201, 'Honeymoon Island', 'Bufflehead', 'Jul', 25, 0.0, 2021, 0.0)
# (202, 'Honeymoon Island', 'Bufflehead', 'Jul', 26, 0.0, 2021, 0.0)
# (203, 'Honeymoon Island', 'Bufflehead', 'Jul', 27, 0.0, 2021, 0.0)
# (204, 'Honeymoon Island', 'Bufflehead', 'Jul', 28, 0.0, 2021, 0.0)
# (205, 'Honeymoon Island', 'Bufflehead', 'Aug', 29, 0.0, 2021, 0.0)
# (206, 'Honeymoon Island', 'Bufflehead', 'Aug', 30, 0.0, 2021, 0.0)
# (207, 'Honeymoon Island', 'Bufflehead', 'Aug', 31, 0.0, 2021, 0.0)
# (208, 'Honeymoon Island', 'Bufflehead', 'Aug', 32, 0.0, 2021, 0.0)
# (209, 'Honeymoon Island', 'Bufflehead', 'Sep', 33, 0.0, 2021, 0.0)
# (210, 'Honeymoon Island', 'Bufflehead', 'Sep', 34, 0.0, 2021, 0.0)
# (211, 'Honeymoon Island', 'Bufflehead', 'Sep', 35, 0.0, 2021, 0.0)
# (212, 'Honeymoon Island', 'Bufflehead', 'Sep', 36, 0.0, 2021, 0.0)
# (213, 'Honeymoon Island', 'Bufflehead', 'Oct', 37, 0.0, 2021, 0.0)
# (214, 'Honeymoon Island', 'Bufflehead', 'Oct', 38, 0.0, 2021, 0.0)
# (215, 'Honeymoon Island', 'Bufflehead', 'Oct', 39, 0.0, 2021, 0.0)
# (216, 'Honeymoon Island', 'Bufflehead', 'Oct', 40, 0.0, 2021, 0.0)
# (217, 'Honeymoon Island', 'Bufflehead', 'Nov', 41, 0.0, 2021, 0.0)
# (218, 'Honeymoon Island', 'Bufflehead', 'Nov', 42, 0.0, 2021, 0.0)
# (219, 'Honeymoon Island', 'Bufflehead', 'Nov', 43, 0.0, 2021, 0.0)
# (220, 'Honeymoon Island', 'Bufflehead', 'Nov', 44, 0.0, 2021, 0.0)
# (221, 'Honeymoon Island', 'Red-breasted Merganser', 'Jan', 1, 10.0, 2021, 0.4)
# (222, 'Honeymoon Island', 'Red-breasted Merganser', 'Jan', 2, 5.0, 2021, 0.0)
# (223, 'Honeymoon Island', 'Red-breasted Merganser', 'Jan', 3, 12.0, 2021, 0.1666667)
# (224, 'Honeymoon Island', 'Red-breasted Merganser', 'Jan', 4, 11.0, 2021, 0.0909091)
# (225, 'Honeymoon Island', 'Red-breasted Merganser', 'Feb', 5, 11.0, 2021, 0.0909091)
# (226, 'Honeymoon Island', 'Red-breasted Merganser', 'Feb', 6, 0.0, 2021, 0.0)
# (227, 'Honeymoon Island', 'Red-breasted Merganser', 'Feb', 7, 0.0, 2021, 0.0)
# (228, 'Honeymoon Island', 'Red-breasted Merganser', 'Feb', 8, 0.0, 2021, 0.0)
# (229, 'Honeymoon Island', 'Red-breasted Merganser', 'Mar', 9, 0.0, 2021, 0.0)
# (230, 'Honeymoon Island', 'Red-breasted Merganser', 'Mar', 10, 0.0, 2021, 0.0)
# (231, 'Honeymoon Island', 'Red-breasted Merganser', 'Mar', 11, 0.0, 2021, 0.0)
# (232, 'Honeymoon Island', 'Red-breasted Merganser', 'Mar', 12, 0.0, 2021, 0.0)
# (233, 'Honeymoon Island', 'Red-breasted Merganser', 'Apr', 13, 0.0, 2021, 0.0)
# (234, 'Honeymoon Island', 'Red-breasted Merganser', 'Apr', 14, 0.0, 2021, 0.0)
# (235, 'Honeymoon Island', 'Red-breasted Merganser', 'Apr', 15, 0.0, 2021, 0.0)
# (236, 'Honeymoon Island', 'Red-breasted Merganser', 'Apr', 16, 0.0, 2021, 0.0)
# (237, 'Honeymoon Island', 'Red-breasted Merganser', 'May', 17, 0.0, 2021, 0.0)
# (238, 'Honeymoon Island', 'Red-breasted Merganser', 'May', 18, 0.0, 2021, 0.0)
# (239, 'Honeymoon Island', 'Red-breasted Merganser', 'May', 19, 0.0, 2021, 0.0)
# (240, 'Honeymoon Island', 'Red-breasted Merganser', 'May', 20, 0.0, 2021, 0.0)
# (241, 'Honeymoon Island', 'Red-breasted Merganser', 'Jun', 21, 0.0, 2021, 0.0)
# (242, 'Honeymoon Island', 'Red-breasted Merganser', 'Jun', 22, 0.0, 2021, 0.0)
# (243, 'Honeymoon Island', 'Red-breasted Merganser', 'Jun', 23, 0.0, 2021, 0.0)
# (244, 'Honeymoon Island', 'Red-breasted Merganser', 'Jun', 24, 0.0, 2021, 0.0)
# (245, 'Honeymoon Island', 'Red-breasted Merganser', 'Jul', 25, 0.0, 2021, 0.0)
# (246, 'Honeymoon Island', 'Red-breasted Merganser', 'Jul', 26, 0.0, 2021, 0.0)
# (247, 'Honeymoon Island', 'Red-breasted Merganser', 'Jul', 27, 0.0, 2021, 0.0)
# (248, 'Honeymoon Island', 'Red-breasted Merganser', 'Jul', 28, 0.0, 2021, 0.0)
# (249, 'Honeymoon Island', 'Red-breasted Merganser', 'Aug', 29, 0.0, 2021, 0.0)
# (250, 'Honeymoon Island', 'Red-breasted Merganser', 'Aug', 30, 0.0, 2021, 0.0)
# (251, 'Honeymoon Island', 'Red-breasted Merganser', 'Aug', 31, 0.0, 2021, 0.0)
# (252, 'Honeymoon Island', 'Red-breasted Merganser', 'Aug', 32, 0.0, 2021, 0.0)
# (253, 'Honeymoon Island', 'Red-breasted Merganser', 'Sep', 33, 0.0, 2021, 0.0)
# (254, 'Honeymoon Island', 'Red-breasted Merganser', 'Sep', 34, 0.0, 2021, 0.0)
# (255, 'Honeymoon Island', 'Red-breasted Merganser', 'Sep', 35, 0.0, 2021, 0.0)
# (256, 'Honeymoon Island', 'Red-breasted Merganser', 'Sep', 36, 0.0, 2021, 0.0)
# (257, 'Honeymoon Island', 'Red-breasted Merganser', 'Oct', 37, 0.0, 2021, 0.0)
# (258, 'Honeymoon Island', 'Red-breasted Merganser', 'Oct', 38, 0.0, 2021, 0.0)
# (259, 'Honeymoon Island', 'Red-breasted Merganser', 'Oct', 39, 0.0, 2021, 0.0)
# (260, 'Honeymoon Island', 'Red-breasted Merganser', 'Oct', 40, 0.0, 2021, 0.0)
# (261, 'Honeymoon Island', 'Red-breasted Merganser', 'Nov', 41, 0.0, 2021, 0.0)
# (262, 'Honeymoon Island', 'Red-breasted Merganser', 'Nov', 42, 0.0, 2021, 0.0)
# (263, 'Honeymoon Island', 'Red-breasted Merganser', 'Nov', 43, 0.0, 2021, 0.0)
# (264, 'Honeymoon Island', 'Red-breasted Merganser', 'Nov', 44, 0.0, 2021, 0.0)
# (265, 'Honeymoon Island', 'Pied-billed Grebe', 'Jan', 1, 10.0, 2021, 0.0)
# (266, 'Honeymoon Island', 'Pied-billed Grebe', 'Jan', 2, 5.0, 2021, 0.0)
# (267, 'Honeymoon Island', 'Pied-billed Grebe', 'Jan', 3, 12.0, 2021, 0.0)
# (268, 'Honeymoon Island', 'Pied-billed Grebe', 'Jan', 4, 11.0, 2021, 0.0909091)
# (269, 'Honeymoon Island', 'Pied-billed Grebe', 'Feb', 5, 11.0, 2021, 0.0909091)
# (270, 'Honeymoon Island', 'Pied-billed Grebe', 'Feb', 6, 0.0, 2021, 0.0)
# (271, 'Honeymoon Island', 'Pied-billed Grebe', 'Feb', 7, 0.0, 2021, 0.0)
# (272, 'Honeymoon Island', 'Pied-billed Grebe', 'Feb', 8, 0.0, 2021, 0.0)
# (273, 'Honeymoon Island', 'Pied-billed Grebe', 'Mar', 9, 0.0, 2021, 0.0)
# (274, 'Honeymoon Island', 'Pied-billed Grebe', 'Mar', 10, 0.0, 2021, 0.0)
# (275, 'Honeymoon Island', 'Pied-billed Grebe', 'Mar', 11, 0.0, 2021, 0.0)
# (276, 'Honeymoon Island', 'Pied-billed Grebe', 'Mar', 12, 0.0, 2021, 0.0)
# (277, 'Honeymoon Island', 'Pied-billed Grebe', 'Apr', 13, 0.0, 2021, 0.0)
# (278, 'Honeymoon Island', 'Pied-billed Grebe', 'Apr', 14, 0.0, 2021, 0.0)
# (279, 'Honeymoon Island', 'Pied-billed Grebe', 'Apr', 15, 0.0, 2021, 0.0)
# (280, 'Honeymoon Island', 'Pied-billed Grebe', 'Apr', 16, 0.0, 2021, 0.0)
# (281, 'Honeymoon Island', 'Pied-billed Grebe', 'May', 17, 0.0, 2021, 0.0)
# (282, 'Honeymoon Island', 'Pied-billed Grebe', 'May', 18, 0.0, 2021, 0.0)
# (283, 'Honeymoon Island', 'Pied-billed Grebe', 'May', 19, 0.0, 2021, 0.0)
# (284, 'Honeymoon Island', 'Pied-billed Grebe', 'May', 20, 0.0, 2021, 0.0)
# (285, 'Honeymoon Island', 'Pied-billed Grebe', 'Jun', 21, 0.0, 2021, 0.0)
# (286, 'Honeymoon Island', 'Pied-billed Grebe', 'Jun', 22, 0.0, 2021, 0.0)
# (287, 'Honeymoon Island', 'Pied-billed Grebe', 'Jun', 23, 0.0, 2021, 0.0)
# (288, 'Honeymoon Island', 'Pied-billed Grebe', 'Jun', 24, 0.0, 2021, 0.0)
# (289, 'Honeymoon Island', 'Pied-billed Grebe', 'Jul', 25, 0.0, 2021, 0.0)
# (290, 'Honeymoon Island', 'Pied-billed Grebe', 'Jul', 26, 0.0, 2021, 0.0)
# (291, 'Honeymoon Island', 'Pied-billed Grebe', 'Jul', 27, 0.0, 2021, 0.0)
# (292, 'Honeymoon Island', 'Pied-billed Grebe', 'Jul', 28, 0.0, 2021, 0.0)
# (293, 'Honeymoon Island', 'Pied-billed Grebe', 'Aug', 29, 0.0, 2021, 0.0)
# (294, 'Honeymoon Island', 'Pied-billed Grebe', 'Aug', 30, 0.0, 2021, 0.0)
# (295, 'Honeymoon Island', 'Pied-billed Grebe', 'Aug', 31, 0.0, 2021, 0.0)
# (296, 'Honeymoon Island', 'Pied-billed Grebe', 'Aug', 32, 0.0, 2021, 0.0)
# (297, 'Honeymoon Island', 'Pied-billed Grebe', 'Sep', 33, 0.0, 2021, 0.0)
# (298, 'Honeymoon Island', 'Pied-billed Grebe', 'Sep', 34, 0.0, 2021, 0.0)
# (299, 'Honeymoon Island', 'Pied-billed Grebe', 'Sep', 35, 0.0, 2021, 0.0)
# (300, 'Honeymoon Island', 'Pied-billed Grebe', 'Sep', 36, 0.0, 2021, 0.0)
# (301, 'Honeymoon Island', 'Pied-billed Grebe', 'Oct', 37, 0.0, 2021, 0.0)
# (302, 'Honeymoon Island', 'Pied-billed Grebe', 'Oct', 38, 0.0, 2021, 0.0)
# (303, 'Honeymoon Island', 'Pied-billed Grebe', 'Oct', 39, 0.0, 2021, 0.0)
# (304, 'Honeymoon Island', 'Pied-billed Grebe', 'Oct', 40, 0.0, 2021, 0.0)
# (305, 'Honeymoon Island', 'Pied-billed Grebe', 'Nov', 41, 0.0, 2021, 0.0)
# (306, 'Honeymoon Island', 'Pied-billed Grebe', 'Nov', 42, 0.0, 2021, 0.0)
# (307, 'Honeymoon Island', 'Pied-billed Grebe', 'Nov', 43, 0.0, 2021, 0.0)
# (308, 'Honeymoon Island', 'Pied-billed Grebe', 'Nov', 44, 0.0, 2021, 0.0)
# (309, 'Honeymoon Island', 'Horned Grebe', 'Jan', 1, 10.0, 2021, 0.1)
# (310, 'Honeymoon Island', 'Horned Grebe', 'Jan', 2, 5.0, 2021, 0.0)
# (311, 'Honeymoon Island', 'Horned Grebe', 'Jan', 3, 12.0, 2021, 0.0833333)
# (312, 'Honeymoon Island', 'Horned Grebe', 'Jan', 4, 11.0, 2021, 0.0)
# (313, 'Honeymoon Island', 'Horned Grebe', 'Feb', 5, 11.0, 2021, 0.0909091)
# (314, 'Honeymoon Island', 'Horned Grebe', 'Feb', 6, 0.0, 2021, 0.0)
# (315, 'Honeymoon Island', 'Horned Grebe', 'Feb', 7, 0.0, 2021, 0.0)
# (316, 'Honeymoon Island', 'Horned Grebe', 'Feb', 8, 0.0, 2021, 0.0)
# (317, 'Honeymoon Island', 'Horned Grebe', 'Mar', 9, 0.0, 2021, 0.0)
# (318, 'Honeymoon Island', 'Horned Grebe', 'Mar', 10, 0.0, 2021, 0.0)
# (319, 'Honeymoon Island', 'Horned Grebe', 'Mar', 11, 0.0, 2021, 0.0)
# (320, 'Honeymoon Island', 'Horned Grebe', 'Mar', 12, 0.0, 2021, 0.0)
# (321, 'Honeymoon Island', 'Horned Grebe', 'Apr', 13, 0.0, 2021, 0.0)
# (322, 'Honeymoon Island', 'Horned Grebe', 'Apr', 14, 0.0, 2021, 0.0)
# (323, 'Honeymoon Island', 'Horned Grebe', 'Apr', 15, 0.0, 2021, 0.0)
# (324, 'Honeymoon Island', 'Horned Grebe', 'Apr', 16, 0.0, 2021, 0.0)
# (325, 'Honeymoon Island', 'Horned Grebe', 'May', 17, 0.0, 2021, 0.0)
# (326, 'Honeymoon Island', 'Horned Grebe', 'May', 18, 0.0, 2021, 0.0)
# (327, 'Honeymoon Island', 'Horned Grebe', 'May', 19, 0.0, 2021, 0.0)
# (328, 'Honeymoon Island', 'Horned Grebe', 'May', 20, 0.0, 2021, 0.0)
# (329, 'Honeymoon Island', 'Horned Grebe', 'Jun', 21, 0.0, 2021, 0.0)
# (330, 'Honeymoon Island', 'Horned Grebe', 'Jun', 22, 0.0, 2021, 0.0)
# (331, 'Honeymoon Island', 'Horned Grebe', 'Jun', 23, 0.0, 2021, 0.0)
# (332, 'Honeymoon Island', 'Horned Grebe', 'Jun', 24, 0.0, 2021, 0.0)
# (333, 'Honeymoon Island', 'Horned Grebe', 'Jul', 25, 0.0, 2021, 0.0)
# (334, 'Honeymoon Island', 'Horned Grebe', 'Jul', 26, 0.0, 2021, 0.0)
# (335, 'Honeymoon Island', 'Horned Grebe', 'Jul', 27, 0.0, 2021, 0.0)
# (336, 'Honeymoon Island', 'Horned Grebe', 'Jul', 28, 0.0, 2021, 0.0)
# (337, 'Honeymoon Island', 'Horned Grebe', 'Aug', 29, 0.0, 2021, 0.0)
# (338, 'Honeymoon Island', 'Horned Grebe', 'Aug', 30, 0.0, 2021, 0.0)
# (339, 'Honeymoon Island', 'Horned Grebe', 'Aug', 31, 0.0, 2021, 0.0)
# (340, 'Honeymoon Island', 'Horned Grebe', 'Aug', 32, 0.0, 2021, 0.0)
# (341, 'Honeymoon Island', 'Horned Grebe', 'Sep', 33, 0.0, 2021, 0.0)
# (342, 'Honeymoon Island', 'Horned Grebe', 'Sep', 34, 0.0, 2021, 0.0)
# (343, 'Honeymoon Island', 'Horned Grebe', 'Sep', 35, 0.0, 2021, 0.0)
# (344, 'Honeymoon Island', 'Horned Grebe', 'Sep', 36, 0.0, 2021, 0.0)
# (345, 'Honeymoon Island', 'Horned Grebe', 'Oct', 37, 0.0, 2021, 0.0)
# (346, 'Honeymoon Island', 'Horned Grebe', 'Oct', 38, 0.0, 2021, 0.0)
# (347, 'Honeymoon Island', 'Horned Grebe', 'Oct', 39, 0.0, 2021, 0.0)
# (348, 'Honeymoon Island', 'Horned Grebe', 'Oct', 40, 0.0, 2021, 0.0)
# (349, 'Honeymoon Island', 'Horned Grebe', 'Nov', 41, 0.0, 2021, 0.0)
# (350, 'Honeymoon Island', 'Horned Grebe', 'Nov', 42, 0.0, 2021, 0.0)
# (351, 'Honeymoon Island', 'Horned Grebe', 'Nov', 43, 0.0, 2021, 0.0)
# (352, 'Honeymoon Island', 'Horned Grebe', 'Nov', 44, 0.0, 2021, 0.0)
# (353, 'Honeymoon Island', 'Rock Pigeon', 'Jan', 1, 10.0, 2021, 0.1)
# (354, 'Honeymoon Island', 'Rock Pigeon', 'Jan', 2, 5.0, 2021, 0.0)
# (355, 'Honeymoon Island', 'Rock Pigeon', 'Jan', 3, 12.0, 2021, 0.0833333)
# (356, 'Honeymoon Island', 'Rock Pigeon', 'Jan', 4, 11.0, 2021, 0.0909091)
# (357, 'Honeymoon Island', 'Rock Pigeon', 'Feb', 5, 11.0, 2021, 0.0)
# (358, 'Honeymoon Island', 'Rock Pigeon', 'Feb', 6, 0.0, 2021, 0.0)
# (359, 'Honeymoon Island', 'Rock Pigeon', 'Feb', 7, 0.0, 2021, 0.0)
# (360, 'Honeymoon Island', 'Rock Pigeon', 'Feb', 8, 0.0, 2021, 0.0)
# (361, 'Honeymoon Island', 'Rock Pigeon', 'Mar', 9, 0.0, 2021, 0.0)
# (362, 'Honeymoon Island', 'Rock Pigeon', 'Mar', 10, 0.0, 2021, 0.0)
# (363, 'Honeymoon Island', 'Rock Pigeon', 'Mar', 11, 0.0, 2021, 0.0)
# (364, 'Honeymoon Island', 'Rock Pigeon', 'Mar', 12, 0.0, 2021, 0.0)
# (365, 'Honeymoon Island', 'Rock Pigeon', 'Apr', 13, 0.0, 2021, 0.0)
# (366, 'Honeymoon Island', 'Rock Pigeon', 'Apr', 14, 0.0, 2021, 0.0)
# (367, 'Honeymoon Island', 'Rock Pigeon', 'Apr', 15, 0.0, 2021, 0.0)
# (368, 'Honeymoon Island', 'Rock Pigeon', 'Apr', 16, 0.0, 2021, 0.0)
# (369, 'Honeymoon Island', 'Rock Pigeon', 'May', 17, 0.0, 2021, 0.0)
# (370, 'Honeymoon Island', 'Rock Pigeon', 'May', 18, 0.0, 2021, 0.0)
# (371, 'Honeymoon Island', 'Rock Pigeon', 'May', 19, 0.0, 2021, 0.0)
# (372, 'Honeymoon Island', 'Rock Pigeon', 'May', 20, 0.0, 2021, 0.0)
# (373, 'Honeymoon Island', 'Rock Pigeon', 'Jun', 21, 0.0, 2021, 0.0)
# (374, 'Honeymoon Island', 'Rock Pigeon', 'Jun', 22, 0.0, 2021, 0.0)
# (375, 'Honeymoon Island', 'Rock Pigeon', 'Jun', 23, 0.0, 2021, 0.0)
# (376, 'Honeymoon Island', 'Rock Pigeon', 'Jun', 24, 0.0, 2021, 0.0)
# (377, 'Honeymoon Island', 'Rock Pigeon', 'Jul', 25, 0.0, 2021, 0.0)
# (378, 'Honeymoon Island', 'Rock Pigeon', 'Jul', 26, 0.0, 2021, 0.0)
# (379, 'Honeymoon Island', 'Rock Pigeon', 'Jul', 27, 0.0, 2021, 0.0)
# (380, 'Honeymoon Island', 'Rock Pigeon', 'Jul', 28, 0.0, 2021, 0.0)
# (381, 'Honeymoon Island', 'Rock Pigeon', 'Aug', 29, 0.0, 2021, 0.0)
# (382, 'Honeymoon Island', 'Rock Pigeon', 'Aug', 30, 0.0, 2021, 0.0)
# (383, 'Honeymoon Island', 'Rock Pigeon', 'Aug', 31, 0.0, 2021, 0.0)
# (384, 'Honeymoon Island', 'Rock Pigeon', 'Aug', 32, 0.0, 2021, 0.0)
# (385, 'Honeymoon Island', 'Rock Pigeon', 'Sep', 33, 0.0, 2021, 0.0)
# (386, 'Honeymoon Island', 'Rock Pigeon', 'Sep', 34, 0.0, 2021, 0.0)
# (387, 'Honeymoon Island', 'Rock Pigeon', 'Sep', 35, 0.0, 2021, 0.0)
# (388, 'Honeymoon Island', 'Rock Pigeon', 'Sep', 36, 0.0, 2021, 0.0)
# (389, 'Honeymoon Island', 'Rock Pigeon', 'Oct', 37, 0.0, 2021, 0.0)
# (390, 'Honeymoon Island', 'Rock Pigeon', 'Oct', 38, 0.0, 2021, 0.0)
# (391, 'Honeymoon Island', 'Rock Pigeon', 'Oct', 39, 0.0, 2021, 0.0)
# (392, 'Honeymoon Island', 'Rock Pigeon', 'Oct', 40, 0.0, 2021, 0.0)
# (393, 'Honeymoon Island', 'Rock Pigeon', 'Nov', 41, 0.0, 2021, 0.0)
# (394, 'Honeymoon Island', 'Rock Pigeon', 'Nov', 42, 0.0, 2021, 0.0)
# (395, 'Honeymoon Island', 'Rock Pigeon', 'Nov', 43, 0.0, 2021, 0.0)
# (396, 'Honeymoon Island', 'Rock Pigeon', 'Nov', 44, 0.0, 2021, 0.0)
# (397, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jan', 1, 10.0, 2021, 0.0)
# (398, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jan', 2, 5.0, 2021, 0.2)
# (399, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jan', 3, 12.0, 2021, 0.0833333)
# (400, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jan', 4, 11.0, 2021, 0.1818182)
# (401, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Feb', 5, 11.0, 2021, 0.0)
# (402, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Feb', 6, 0.0, 2021, 0.0)
# (403, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Feb', 7, 0.0, 2021, 0.0)
# (404, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Feb', 8, 0.0, 2021, 0.0)
# (405, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Mar', 9, 0.0, 2021, 0.0)
# (406, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Mar', 10, 0.0, 2021, 0.0)
# (407, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Mar', 11, 0.0, 2021, 0.0)
# (408, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Mar', 12, 0.0, 2021, 0.0)
# (409, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Apr', 13, 0.0, 2021, 0.0)
# (410, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Apr', 14, 0.0, 2021, 0.0)
# (411, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Apr', 15, 0.0, 2021, 0.0)
# (412, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Apr', 16, 0.0, 2021, 0.0)
# (413, 'Honeymoon Island', 'Eurasian Collared-Dove', 'May', 17, 0.0, 2021, 0.0)
# (414, 'Honeymoon Island', 'Eurasian Collared-Dove', 'May', 18, 0.0, 2021, 0.0)
# (415, 'Honeymoon Island', 'Eurasian Collared-Dove', 'May', 19, 0.0, 2021, 0.0)
# (416, 'Honeymoon Island', 'Eurasian Collared-Dove', 'May', 20, 0.0, 2021, 0.0)
# (417, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jun', 21, 0.0, 2021, 0.0)
# (418, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jun', 22, 0.0, 2021, 0.0)
# (419, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jun', 23, 0.0, 2021, 0.0)
# (420, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jun', 24, 0.0, 2021, 0.0)
# (421, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jul', 25, 0.0, 2021, 0.0)
# (422, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jul', 26, 0.0, 2021, 0.0)
# (423, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jul', 27, 0.0, 2021, 0.0)
# (424, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Jul', 28, 0.0, 2021, 0.0)
# (425, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Aug', 29, 0.0, 2021, 0.0)
# (426, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Aug', 30, 0.0, 2021, 0.0)
# (427, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Aug', 31, 0.0, 2021, 0.0)
# (428, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Aug', 32, 0.0, 2021, 0.0)
# (429, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Sep', 33, 0.0, 2021, 0.0)
# (430, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Sep', 34, 0.0, 2021, 0.0)
# (431, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Sep', 35, 0.0, 2021, 0.0)
# (432, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Sep', 36, 0.0, 2021, 0.0)
# (433, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Oct', 37, 0.0, 2021, 0.0)
# (434, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Oct', 38, 0.0, 2021, 0.0)
# (435, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Oct', 39, 0.0, 2021, 0.0)
# (436, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Oct', 40, 0.0, 2021, 0.0)
# (437, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Nov', 41, 0.0, 2021, 0.0)
# (438, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Nov', 42, 0.0, 2021, 0.0)
# (439, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Nov', 43, 0.0, 2021, 0.0)
# (440, 'Honeymoon Island', 'Eurasian Collared-Dove', 'Nov', 44, 0.0, 2021, 0.0)
# (441, 'Honeymoon Island', 'Common Ground Dove', 'Jan', 1, 10.0, 2021, 0.7)
# (442, 'Honeymoon Island', 'Common Ground Dove', 'Jan', 2, 5.0, 2021, 1.0)
# (443, 'Honeymoon Island', 'Common Ground Dove', 'Jan', 3, 12.0, 2021, 0.8333333)
# (444, 'Honeymoon Island', 'Common Ground Dove', 'Jan', 4, 11.0, 2021, 0.6363636)
# (445, 'Honeymoon Island', 'Common Ground Dove', 'Feb', 5, 11.0, 2021, 0.5454545)
# (446, 'Honeymoon Island', 'Common Ground Dove', 'Feb', 6, 0.0, 2021, 0.0)
# (447, 'Honeymoon Island', 'Common Ground Dove', 'Feb', 7, 0.0, 2021, 0.0)
# (448, 'Honeymoon Island', 'Common Ground Dove', 'Feb', 8, 0.0, 2021, 0.0)
# (449, 'Honeymoon Island', 'Common Ground Dove', 'Mar', 9, 0.0, 2021, 0.0)
# (450, 'Honeymoon Island', 'Common Ground Dove', 'Mar', 10, 0.0, 2021, 0.0)
# (451, 'Honeymoon Island', 'Common Ground Dove', 'Mar', 11, 0.0, 2021, 0.0)
# (452, 'Honeymoon Island', 'Common Ground Dove', 'Mar', 12, 0.0, 2021, 0.0)
# (453, 'Honeymoon Island', 'Common Ground Dove', 'Apr', 13, 0.0, 2021, 0.0)
# (454, 'Honeymoon Island', 'Common Ground Dove', 'Apr', 14, 0.0, 2021, 0.0)
# (455, 'Honeymoon Island', 'Common Ground Dove', 'Apr', 15, 0.0, 2021, 0.0)
# (456, 'Honeymoon Island', 'Common Ground Dove', 'Apr', 16, 0.0, 2021, 0.0)
# (457, 'Honeymoon Island', 'Common Ground Dove', 'May', 17, 0.0, 2021, 0.0)
# (458, 'Honeymoon Island', 'Common Ground Dove', 'May', 18, 0.0, 2021, 0.0)
# (459, 'Honeymoon Island', 'Common Ground Dove', 'May', 19, 0.0, 2021, 0.0)
# (460, 'Honeymoon Island', 'Common Ground Dove', 'May', 20, 0.0, 2021, 0.0)
# (461, 'Honeymoon Island', 'Common Ground Dove', 'Jun', 21, 0.0, 2021, 0.0)
# (462, 'Honeymoon Island', 'Common Ground Dove', 'Jun', 22, 0.0, 2021, 0.0)
# (463, 'Honeymoon Island', 'Common Ground Dove', 'Jun', 23, 0.0, 2021, 0.0)
# (464, 'Honeymoon Island', 'Common Ground Dove', 'Jun', 24, 0.0, 2021, 0.0)
# (465, 'Honeymoon Island', 'Common Ground Dove', 'Jul', 25, 0.0, 2021, 0.0)
# (466, 'Honeymoon Island', 'Common Ground Dove', 'Jul', 26, 0.0, 2021, 0.0)
# (467, 'Honeymoon Island', 'Common Ground Dove', 'Jul', 27, 0.0, 2021, 0.0)
# (468, 'Honeymoon Island', 'Common Ground Dove', 'Jul', 28, 0.0, 2021, 0.0)
# (469, 'Honeymoon Island', 'Common Ground Dove', 'Aug', 29, 0.0, 2021, 0.0)
# (470, 'Honeymoon Island', 'Common Ground Dove', 'Aug', 30, 0.0, 2021, 0.0)
# (471, 'Honeymoon Island', 'Common Ground Dove', 'Aug', 31, 0.0, 2021, 0.0)
# (472, 'Honeymoon Island', 'Common Ground Dove', 'Aug', 32, 0.0, 2021, 0.0)
# (473, 'Honeymoon Island', 'Common Ground Dove', 'Sep', 33, 0.0, 2021, 0.0)
# (474, 'Honeymoon Island', 'Common Ground Dove', 'Sep', 34, 0.0, 2021, 0.0)
# (475, 'Honeymoon Island', 'Common Ground Dove', 'Sep', 35, 0.0, 2021, 0.0)
# (476, 'Honeymoon Island', 'Common Ground Dove', 'Sep', 36, 0.0, 2021, 0.0)
# (477, 'Honeymoon Island', 'Common Ground Dove', 'Oct', 37, 0.0, 2021, 0.0)
# (478, 'Honeymoon Island', 'Common Ground Dove', 'Oct', 38, 0.0, 2021, 0.0)
# (479, 'Honeymoon Island', 'Common Ground Dove', 'Oct', 39, 0.0, 2021, 0.0)
# (480, 'Honeymoon Island', 'Common Ground Dove', 'Oct', 40, 0.0, 2021, 0.0)
# (481, 'Honeymoon Island', 'Common Ground Dove', 'Nov', 41, 0.0, 2021, 0.0)
# (482, 'Honeymoon Island', 'Common Ground Dove', 'Nov', 42, 0.0, 2021, 0.0)
# (483, 'Honeymoon Island', 'Common Ground Dove', 'Nov', 43, 0.0, 2021, 0.0)
# (484, 'Honeymoon Island', 'Common Ground Dove', 'Nov', 44, 0.0, 2021, 0.0)
# (485, 'Honeymoon Island', 'Mourning Dove', 'Jan', 1, 10.0, 2021, 0.6)
# (486, 'Honeymoon Island', 'Mourning Dove', 'Jan', 2, 5.0, 2021, 0.6)
# (487, 'Honeymoon Island', 'Mourning Dove', 'Jan', 3, 12.0, 2021, 0.75)
# (488, 'Honeymoon Island', 'Mourning Dove', 'Jan', 4, 11.0, 2021, 0.5454545)
# (489, 'Honeymoon Island', 'Mourning Dove', 'Feb', 5, 11.0, 2021, 0.6363636)
# (490, 'Honeymoon Island', 'Mourning Dove', 'Feb', 6, 0.0, 2021, 0.0)
# (491, 'Honeymoon Island', 'Mourning Dove', 'Feb', 7, 0.0, 2021, 0.0)
# (492, 'Honeymoon Island', 'Mourning Dove', 'Feb', 8, 0.0, 2021, 0.0)
# (493, 'Honeymoon Island', 'Mourning Dove', 'Mar', 9, 0.0, 2021, 0.0)
# (494, 'Honeymoon Island', 'Mourning Dove', 'Mar', 10, 0.0, 2021, 0.0)
# (495, 'Honeymoon Island', 'Mourning Dove', 'Mar', 11, 0.0, 2021, 0.0)
# (496, 'Honeymoon Island', 'Mourning Dove', 'Mar', 12, 0.0, 2021, 0.0)
# (497, 'Honeymoon Island', 'Mourning Dove', 'Apr', 13, 0.0, 2021, 0.0)
# (498, 'Honeymoon Island', 'Mourning Dove', 'Apr', 14, 0.0, 2021, 0.0)
# (499, 'Honeymoon Island', 'Mourning Dove', 'Apr', 15, 0.0, 2021, 0.0)
# (500, 'Honeymoon Island', 'Mourning Dove', 'Apr', 16, 0.0, 2021, 0.0)
# (501, 'Honeymoon Island', 'Mourning Dove', 'May', 17, 0.0, 2021, 0.0)
# (502, 'Honeymoon Island', 'Mourning Dove', 'May', 18, 0.0, 2021, 0.0)
# (503, 'Honeymoon Island', 'Mourning Dove', 'May', 19, 0.0, 2021, 0.0)
# (504, 'Honeymoon Island', 'Mourning Dove', 'May', 20, 0.0, 2021, 0.0)
# (505, 'Honeymoon Island', 'Mourning Dove', 'Jun', 21, 0.0, 2021, 0.0)
# (506, 'Honeymoon Island', 'Mourning Dove', 'Jun', 22, 0.0, 2021, 0.0)
# (507, 'Honeymoon Island', 'Mourning Dove', 'Jun', 23, 0.0, 2021, 0.0)
# (508, 'Honeymoon Island', 'Mourning Dove', 'Jun', 24, 0.0, 2021, 0.0)
# (509, 'Honeymoon Island', 'Mourning Dove', 'Jul', 25, 0.0, 2021, 0.0)
# (510, 'Honeymoon Island', 'Mourning Dove', 'Jul', 26, 0.0, 2021, 0.0)
# (511, 'Honeymoon Island', 'Mourning Dove', 'Jul', 27, 0.0, 2021, 0.0)
# (512, 'Honeymoon Island', 'Mourning Dove', 'Jul', 28, 0.0, 2021, 0.0)
# (513, 'Honeymoon Island', 'Mourning Dove', 'Aug', 29, 0.0, 2021, 0.0)
# (514, 'Honeymoon Island', 'Mourning Dove', 'Aug', 30, 0.0, 2021, 0.0)
# (515, 'Honeymoon Island', 'Mourning Dove', 'Aug', 31, 0.0, 2021, 0.0)
# (516, 'Honeymoon Island', 'Mourning Dove', 'Aug', 32, 0.0, 2021, 0.0)
# (517, 'Honeymoon Island', 'Mourning Dove', 'Sep', 33, 0.0, 2021, 0.0)
# (518, 'Honeymoon Island', 'Mourning Dove', 'Sep', 34, 0.0, 2021, 0.0)
# (519, 'Honeymoon Island', 'Mourning Dove', 'Sep', 35, 0.0, 2021, 0.0)
# (520, 'Honeymoon Island', 'Mourning Dove', 'Sep', 36, 0.0, 2021, 0.0)
# (521, 'Honeymoon Island', 'Mourning Dove', 'Oct', 37, 0.0, 2021, 0.0)
# (522, 'Honeymoon Island', 'Mourning Dove', 'Oct', 38, 0.0, 2021, 0.0)
# (523, 'Honeymoon Island', 'Mourning Dove', 'Oct', 39, 0.0, 2021, 0.0)
# (524, 'Honeymoon Island', 'Mourning Dove', 'Oct', 40, 0.0, 2021, 0.0)
# (525, 'Honeymoon Island', 'Mourning Dove', 'Nov', 41, 0.0, 2021, 0.0)
# (526, 'Honeymoon Island', 'Mourning Dove', 'Nov', 42, 0.0, 2021, 0.0)
# (527, 'Honeymoon Island', 'Mourning Dove', 'Nov', 43, 0.0, 2021, 0.0)
# (528, 'Honeymoon Island', 'Mourning Dove', 'Nov', 44, 0.0, 2021, 0.0)
# (529, 'Honeymoon Island', 'American Oystercatcher', 'Jan', 1, 10.0, 2021, 0.4)
# (530, 'Honeymoon Island', 'American Oystercatcher', 'Jan', 2, 5.0, 2021, 0.2)
# (531, 'Honeymoon Island', 'American Oystercatcher', 'Jan', 3, 12.0, 2021, 0.4166667)
# (532, 'Honeymoon Island', 'American Oystercatcher', 'Jan', 4, 11.0, 2021, 0.3636364)
# (533, 'Honeymoon Island', 'American Oystercatcher', 'Feb', 5, 11.0, 2021, 0.4545455)
# (534, 'Honeymoon Island', 'American Oystercatcher', 'Feb', 6, 0.0, 2021, 0.0)
# (535, 'Honeymoon Island', 'American Oystercatcher', 'Feb', 7, 0.0, 2021, 0.0)
# (536, 'Honeymoon Island', 'American Oystercatcher', 'Feb', 8, 0.0, 2021, 0.0)
# (537, 'Honeymoon Island', 'American Oystercatcher', 'Mar', 9, 0.0, 2021, 0.0)
# (538, 'Honeymoon Island', 'American Oystercatcher', 'Mar', 10, 0.0, 2021, 0.0)
# (539, 'Honeymoon Island', 'American Oystercatcher', 'Mar', 11, 0.0, 2021, 0.0)
# (540, 'Honeymoon Island', 'American Oystercatcher', 'Mar', 12, 0.0, 2021, 0.0)
# (541, 'Honeymoon Island', 'American Oystercatcher', 'Apr', 13, 0.0, 2021, 0.0)
# (542, 'Honeymoon Island', 'American Oystercatcher', 'Apr', 14, 0.0, 2021, 0.0)
# (543, 'Honeymoon Island', 'American Oystercatcher', 'Apr', 15, 0.0, 2021, 0.0)
# (544, 'Honeymoon Island', 'American Oystercatcher', 'Apr', 16, 0.0, 2021, 0.0)
# (545, 'Honeymoon Island', 'American Oystercatcher', 'May', 17, 0.0, 2021, 0.0)
# (546, 'Honeymoon Island', 'American Oystercatcher', 'May', 18, 0.0, 2021, 0.0)
# (547, 'Honeymoon Island', 'American Oystercatcher', 'May', 19, 0.0, 2021, 0.0)
# (548, 'Honeymoon Island', 'American Oystercatcher', 'May', 20, 0.0, 2021, 0.0)
# (549, 'Honeymoon Island', 'American Oystercatcher', 'Jun', 21, 0.0, 2021, 0.0)
# (550, 'Honeymoon Island', 'American Oystercatcher', 'Jun', 22, 0.0, 2021, 0.0)
# (551, 'Honeymoon Island', 'American Oystercatcher', 'Jun', 23, 0.0, 2021, 0.0)
# (552, 'Honeymoon Island', 'American Oystercatcher', 'Jun', 24, 0.0, 2021, 0.0)
# (553, 'Honeymoon Island', 'American Oystercatcher', 'Jul', 25, 0.0, 2021, 0.0)
# (554, 'Honeymoon Island', 'American Oystercatcher', 'Jul', 26, 0.0, 2021, 0.0)
# (555, 'Honeymoon Island', 'American Oystercatcher', 'Jul', 27, 0.0, 2021, 0.0)
# (556, 'Honeymoon Island', 'American Oystercatcher', 'Jul', 28, 0.0, 2021, 0.0)
# (557, 'Honeymoon Island', 'American Oystercatcher', 'Aug', 29, 0.0, 2021, 0.0)
# (558, 'Honeymoon Island', 'American Oystercatcher', 'Aug', 30, 0.0, 2021, 0.0)
# (559, 'Honeymoon Island', 'American Oystercatcher', 'Aug', 31, 0.0, 2021, 0.0)
# (560, 'Honeymoon Island', 'American Oystercatcher', 'Aug', 32, 0.0, 2021, 0.0)
# (561, 'Honeymoon Island', 'American Oystercatcher', 'Sep', 33, 0.0, 2021, 0.0)
# (562, 'Honeymoon Island', 'American Oystercatcher', 'Sep', 34, 0.0, 2021, 0.0)
# (563, 'Honeymoon Island', 'American Oystercatcher', 'Sep', 35, 0.0, 2021, 0.0)
# (564, 'Honeymoon Island', 'American Oystercatcher', 'Sep', 36, 0.0, 2021, 0.0)
# (565, 'Honeymoon Island', 'American Oystercatcher', 'Oct', 37, 0.0, 2021, 0.0)
# (566, 'Honeymoon Island', 'American Oystercatcher', 'Oct', 38, 0.0, 2021, 0.0)
# (567, 'Honeymoon Island', 'American Oystercatcher', 'Oct', 39, 0.0, 2021, 0.0)
# (568, 'Honeymoon Island', 'American Oystercatcher', 'Oct', 40, 0.0, 2021, 0.0)
# (569, 'Honeymoon Island', 'American Oystercatcher', 'Nov', 41, 0.0, 2021, 0.0)
# (570, 'Honeymoon Island', 'American Oystercatcher', 'Nov', 42, 0.0, 2021, 0.0)
# (571, 'Honeymoon Island', 'American Oystercatcher', 'Nov', 43, 0.0, 2021, 0.0)
# (572, 'Honeymoon Island', 'American Oystercatcher', 'Nov', 44, 0.0, 2021, 0.0)
# (573, 'Honeymoon Island', 'Black-bellied Plover', 'Jan', 1, 10.0, 2021, 0.6)
# (574, 'Honeymoon Island', 'Black-bellied Plover', 'Jan', 2, 5.0, 2021, 0.0)
# (575, 'Honeymoon Island', 'Black-bellied Plover', 'Jan', 3, 12.0, 2021, 0.4166667)
# (576, 'Honeymoon Island', 'Black-bellied Plover', 'Jan', 4, 11.0, 2021, 0.4545455)
# (577, 'Honeymoon Island', 'Black-bellied Plover', 'Feb', 5, 11.0, 2021, 0.6363636)
# (578, 'Honeymoon Island', 'Black-bellied Plover', 'Feb', 6, 0.0, 2021, 0.0)
# (579, 'Honeymoon Island', 'Black-bellied Plover', 'Feb', 7, 0.0, 2021, 0.0)
# (580, 'Honeymoon Island', 'Black-bellied Plover', 'Feb', 8, 0.0, 2021, 0.0)
# (581, 'Honeymoon Island', 'Black-bellied Plover', 'Mar', 9, 0.0, 2021, 0.0)
# (582, 'Honeymoon Island', 'Black-bellied Plover', 'Mar', 10, 0.0, 2021, 0.0)
# (583, 'Honeymoon Island', 'Black-bellied Plover', 'Mar', 11, 0.0, 2021, 0.0)
# (584, 'Honeymoon Island', 'Black-bellied Plover', 'Mar', 12, 0.0, 2021, 0.0)
# (585, 'Honeymoon Island', 'Black-bellied Plover', 'Apr', 13, 0.0, 2021, 0.0)
# (586, 'Honeymoon Island', 'Black-bellied Plover', 'Apr', 14, 0.0, 2021, 0.0)
# (587, 'Honeymoon Island', 'Black-bellied Plover', 'Apr', 15, 0.0, 2021, 0.0)
# (588, 'Honeymoon Island', 'Black-bellied Plover', 'Apr', 16, 0.0, 2021, 0.0)
# (589, 'Honeymoon Island', 'Black-bellied Plover', 'May', 17, 0.0, 2021, 0.0)
# (590, 'Honeymoon Island', 'Black-bellied Plover', 'May', 18, 0.0, 2021, 0.0)
# (591, 'Honeymoon Island', 'Black-bellied Plover', 'May', 19, 0.0, 2021, 0.0)
# (592, 'Honeymoon Island', 'Black-bellied Plover', 'May', 20, 0.0, 2021, 0.0)
# (593, 'Honeymoon Island', 'Black-bellied Plover', 'Jun', 21, 0.0, 2021, 0.0)
# (594, 'Honeymoon Island', 'Black-bellied Plover', 'Jun', 22, 0.0, 2021, 0.0)
# (595, 'Honeymoon Island', 'Black-bellied Plover', 'Jun', 23, 0.0, 2021, 0.0)
# (596, 'Honeymoon Island', 'Black-bellied Plover', 'Jun', 24, 0.0, 2021, 0.0)
# (597, 'Honeymoon Island', 'Black-bellied Plover', 'Jul', 25, 0.0, 2021, 0.0)
# (598, 'Honeymoon Island', 'Black-bellied Plover', 'Jul', 26, 0.0, 2021, 0.0)
# (599, 'Honeymoon Island', 'Black-bellied Plover', 'Jul', 27, 0.0, 2021, 0.0)
# (600, 'Honeymoon Island', 'Black-bellied Plover', 'Jul', 28, 0.0, 2021, 0.0)
# (601, 'Honeymoon Island', 'Black-bellied Plover', 'Aug', 29, 0.0, 2021, 0.0)
# (602, 'Honeymoon Island', 'Black-bellied Plover', 'Aug', 30, 0.0, 2021, 0.0)
# (603, 'Honeymoon Island', 'Black-bellied Plover', 'Aug', 31, 0.0, 2021, 0.0)
# (604, 'Honeymoon Island', 'Black-bellied Plover', 'Aug', 32, 0.0, 2021, 0.0)
# (605, 'Honeymoon Island', 'Black-bellied Plover', 'Sep', 33, 0.0, 2021, 0.0)
# (606, 'Honeymoon Island', 'Black-bellied Plover', 'Sep', 34, 0.0, 2021, 0.0)
# (607, 'Honeymoon Island', 'Black-bellied Plover', 'Sep', 35, 0.0, 2021, 0.0)
# (608, 'Honeymoon Island', 'Black-bellied Plover', 'Sep', 36, 0.0, 2021, 0.0)
# (609, 'Honeymoon Island', 'Black-bellied Plover', 'Oct', 37, 0.0, 2021, 0.0)
# (610, 'Honeymoon Island', 'Black-bellied Plover', 'Oct', 38, 0.0, 2021, 0.0)
# (611, 'Honeymoon Island', 'Black-bellied Plover', 'Oct', 39, 0.0, 2021, 0.0)
# (612, 'Honeymoon Island', 'Black-bellied Plover', 'Oct', 40, 0.0, 2021, 0.0)
# (613, 'Honeymoon Island', 'Black-bellied Plover', 'Nov', 41, 0.0, 2021, 0.0)
# (614, 'Honeymoon Island', 'Black-bellied Plover', 'Nov', 42, 0.0, 2021, 0.0)
# (615, 'Honeymoon Island', 'Black-bellied Plover', 'Nov', 43, 0.0, 2021, 0.0)
# (616, 'Honeymoon Island', 'Black-bellied Plover', 'Nov', 44, 0.0, 2021, 0.0)
# (617, 'Honeymoon Island', 'Snowy Plover', 'Jan', 1, 10.0, 2021, 0.0)
# (618, 'Honeymoon Island', 'Snowy Plover', 'Jan', 2, 5.0, 2021, 0.0)
# (619, 'Honeymoon Island', 'Snowy Plover', 'Jan', 3, 12.0, 2021, 0.1666667)
# (620, 'Honeymoon Island', 'Snowy Plover', 'Jan', 4, 11.0, 2021, 0.0)
# (621, 'Honeymoon Island', 'Snowy Plover', 'Feb', 5, 11.0, 2021, 0.0909091)
# (622, 'Honeymoon Island', 'Snowy Plover', 'Feb', 6, 0.0, 2021, 0.0)
# (623, 'Honeymoon Island', 'Snowy Plover', 'Feb', 7, 0.0, 2021, 0.0)
# (624, 'Honeymoon Island', 'Snowy Plover', 'Feb', 8, 0.0, 2021, 0.0)
# (625, 'Honeymoon Island', 'Snowy Plover', 'Mar', 9, 0.0, 2021, 0.0)
# (626, 'Honeymoon Island', 'Snowy Plover', 'Mar', 10, 0.0, 2021, 0.0)
# (627, 'Honeymoon Island', 'Snowy Plover', 'Mar', 11, 0.0, 2021, 0.0)
# (628, 'Honeymoon Island', 'Snowy Plover', 'Mar', 12, 0.0, 2021, 0.0)
# (629, 'Honeymoon Island', 'Snowy Plover', 'Apr', 13, 0.0, 2021, 0.0)
# (630, 'Honeymoon Island', 'Snowy Plover', 'Apr', 14, 0.0, 2021, 0.0)
# (631, 'Honeymoon Island', 'Snowy Plover', 'Apr', 15, 0.0, 2021, 0.0)
# (632, 'Honeymoon Island', 'Snowy Plover', 'Apr', 16, 0.0, 2021, 0.0)
# (633, 'Honeymoon Island', 'Snowy Plover', 'May', 17, 0.0, 2021, 0.0)
# (634, 'Honeymoon Island', 'Snowy Plover', 'May', 18, 0.0, 2021, 0.0)
# (635, 'Honeymoon Island', 'Snowy Plover', 'May', 19, 0.0, 2021, 0.0)
# (636, 'Honeymoon Island', 'Snowy Plover', 'May', 20, 0.0, 2021, 0.0)
# (637, 'Honeymoon Island', 'Snowy Plover', 'Jun', 21, 0.0, 2021, 0.0)
# (638, 'Honeymoon Island', 'Snowy Plover', 'Jun', 22, 0.0, 2021, 0.0)
# (639, 'Honeymoon Island', 'Snowy Plover', 'Jun', 23, 0.0, 2021, 0.0)
# (640, 'Honeymoon Island', 'Snowy Plover', 'Jun', 24, 0.0, 2021, 0.0)
# (641, 'Honeymoon Island', 'Snowy Plover', 'Jul', 25, 0.0, 2021, 0.0)
# (642, 'Honeymoon Island', 'Snowy Plover', 'Jul', 26, 0.0, 2021, 0.0)
# (643, 'Honeymoon Island', 'Snowy Plover', 'Jul', 27, 0.0, 2021, 0.0)
# (644, 'Honeymoon Island', 'Snowy Plover', 'Jul', 28, 0.0, 2021, 0.0)
# (645, 'Honeymoon Island', 'Snowy Plover', 'Aug', 29, 0.0, 2021, 0.0)
# (646, 'Honeymoon Island', 'Snowy Plover', 'Aug', 30, 0.0, 2021, 0.0)
# (647, 'Honeymoon Island', 'Snowy Plover', 'Aug', 31, 0.0, 2021, 0.0)
# (648, 'Honeymoon Island', 'Snowy Plover', 'Aug', 32, 0.0, 2021, 0.0)
# (649, 'Honeymoon Island', 'Snowy Plover', 'Sep', 33, 0.0, 2021, 0.0)
# (650, 'Honeymoon Island', 'Snowy Plover', 'Sep', 34, 0.0, 2021, 0.0)
# (651, 'Honeymoon Island', 'Snowy Plover', 'Sep', 35, 0.0, 2021, 0.0)
# (652, 'Honeymoon Island', 'Snowy Plover', 'Sep', 36, 0.0, 2021, 0.0)
# (653, 'Honeymoon Island', 'Snowy Plover', 'Oct', 37, 0.0, 2021, 0.0)
# (654, 'Honeymoon Island', 'Snowy Plover', 'Oct', 38, 0.0, 2021, 0.0)
# (655, 'Honeymoon Island', 'Snowy Plover', 'Oct', 39, 0.0, 2021, 0.0)
# (656, 'Honeymoon Island', 'Snowy Plover', 'Oct', 40, 0.0, 2021, 0.0)
# ...
# (4983, 'Honeymoon Island', 'Pine Warbler', 'Mar', 11, 0.0, 2021, 0.0)
# (4984, 'Honeymoon Island', 'Pine Warbler', 'Mar', 12, 0.0, 2021, 0.0)
# (4985, 'Honeymoon Island', 'Pine Warbler', 'Apr', 13, 0.0, 2021, 0.0)
# (4986, 'Honeymoon Island', 'Pine Warbler', 'Apr', 14, 0.0, 2021, 0.0)
# (4987, 'Honeymoon Island', 'Pine Warbler', 'Apr', 15, 0.0, 2021, 0.0)
# (4988, 'Honeymoon Island', 'Pine Warbler', 'Apr', 16, 0.0, 2021, 0.0)
# (4989, 'Honeymoon Island', 'Pine Warbler', 'May', 17, 0.0, 2021, 0.0)
# (4990, 'Honeymoon Island', 'Pine Warbler', 'May', 18, 0.0, 2021, 0.0)
# (4991, 'Honeymoon Island', 'Pine Warbler', 'May', 19, 0.0, 2021, 0.0)
# (4992, 'Honeymoon Island', 'Pine Warbler', 'May', 20, 0.0, 2021, 0.0)
# (4993, 'Honeymoon Island', 'Pine Warbler', 'Jun', 21, 0.0, 2021, 0.0)
# (4994, 'Honeymoon Island', 'Pine Warbler', 'Jun', 22, 0.0, 2021, 0.0)
# (4995, 'Honeymoon Island', 'Pine Warbler', 'Jun', 23, 0.0, 2021, 0.0)
# (4996, 'Honeymoon Island', 'Pine Warbler', 'Jun', 24, 0.0, 2021, 0.0)
# (4997, 'Honeymoon Island', 'Pine Warbler', 'Jul', 25, 0.0, 2021, 0.0)
# (4998, 'Honeymoon Island', 'Pine Warbler', 'Jul', 26, 0.0, 2021, 0.0)
# (4999, 'Honeymoon Island', 'Pine Warbler', 'Jul', 27, 0.0, 2021, 0.0)
# (5000, 'Honeymoon Island', 'Pine Warbler', 'Jul', 28, 0.0, 2021, 0.0)
# (5001, 'Honeymoon Island', 'Pine Warbler', 'Aug', 29, 0.0, 2021, 0.0)
# (5002, 'Honeymoon Island', 'Pine Warbler', 'Aug', 30, 0.0, 2021, 0.0)
# (5003, 'Honeymoon Island', 'Pine Warbler', 'Aug', 31, 0.0, 2021, 0.0)
# (5004, 'Honeymoon Island', 'Pine Warbler', 'Aug', 32, 0.0, 2021, 0.0)
# (5005, 'Honeymoon Island', 'Pine Warbler', 'Sep', 33, 0.0, 2021, 0.0)
# (5006, 'Honeymoon Island', 'Pine Warbler', 'Sep', 34, 0.0, 2021, 0.0)
# (5007, 'Honeymoon Island', 'Pine Warbler', 'Sep', 35, 0.0, 2021, 0.0)
# (5008, 'Honeymoon Island', 'Pine Warbler', 'Sep', 36, 0.0, 2021, 0.0)
# (5009, 'Honeymoon Island', 'Pine Warbler', 'Oct', 37, 0.0, 2021, 0.0)
# (5010, 'Honeymoon Island', 'Pine Warbler', 'Oct', 38, 0.0, 2021, 0.0)
# (5011, 'Honeymoon Island', 'Pine Warbler', 'Oct', 39, 0.0, 2021, 0.0)
# (5012, 'Honeymoon Island', 'Pine Warbler', 'Oct', 40, 0.0, 2021, 0.0)
# (5013, 'Honeymoon Island', 'Pine Warbler', 'Nov', 41, 0.0, 2021, 0.0)
# (5014, 'Honeymoon Island', 'Pine Warbler', 'Nov', 42, 0.0, 2021, 0.0)
# (5015, 'Honeymoon Island', 'Pine Warbler', 'Nov', 43, 0.0, 2021, 0.0)
# (5016, 'Honeymoon Island', 'Pine Warbler', 'Nov', 44, 0.0, 2021, 0.0)
# (5017, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jan', 1, 10.0, 2021, 0.8)
# (5018, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jan', 2, 5.0, 2021, 0.4)
# (5019, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jan', 3, 12.0, 2021, 0.6666667)
# (5020, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jan', 4, 11.0, 2021, 0.4545455)
# (5021, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Feb', 5, 11.0, 2021, 0.4545455)
# (5022, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Feb', 6, 0.0, 2021, 0.0)
# (5023, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Feb', 7, 0.0, 2021, 0.0)
# (5024, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Feb', 8, 0.0, 2021, 0.0)
# (5025, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Mar', 9, 0.0, 2021, 0.0)
# (5026, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Mar', 10, 0.0, 2021, 0.0)
# (5027, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Mar', 11, 0.0, 2021, 0.0)
# (5028, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Mar', 12, 0.0, 2021, 0.0)
# (5029, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Apr', 13, 0.0, 2021, 0.0)
# (5030, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Apr', 14, 0.0, 2021, 0.0)
# (5031, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Apr', 15, 0.0, 2021, 0.0)
# (5032, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Apr', 16, 0.0, 2021, 0.0)
# (5033, 'Honeymoon Island', 'Yellow-rumped Warbler', 'May', 17, 0.0, 2021, 0.0)
# (5034, 'Honeymoon Island', 'Yellow-rumped Warbler', 'May', 18, 0.0, 2021, 0.0)
# (5035, 'Honeymoon Island', 'Yellow-rumped Warbler', 'May', 19, 0.0, 2021, 0.0)
# (5036, 'Honeymoon Island', 'Yellow-rumped Warbler', 'May', 20, 0.0, 2021, 0.0)
# (5037, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jun', 21, 0.0, 2021, 0.0)
# (5038, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jun', 22, 0.0, 2021, 0.0)
# (5039, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jun', 23, 0.0, 2021, 0.0)
# (5040, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jun', 24, 0.0, 2021, 0.0)
# (5041, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jul', 25, 0.0, 2021, 0.0)
# (5042, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jul', 26, 0.0, 2021, 0.0)
# (5043, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jul', 27, 0.0, 2021, 0.0)
# (5044, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Jul', 28, 0.0, 2021, 0.0)
# (5045, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Aug', 29, 0.0, 2021, 0.0)
# (5046, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Aug', 30, 0.0, 2021, 0.0)
# (5047, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Aug', 31, 0.0, 2021, 0.0)
# (5048, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Aug', 32, 0.0, 2021, 0.0)
# (5049, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Sep', 33, 0.0, 2021, 0.0)
# (5050, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Sep', 34, 0.0, 2021, 0.0)
# (5051, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Sep', 35, 0.0, 2021, 0.0)
# (5052, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Sep', 36, 0.0, 2021, 0.0)
# (5053, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Oct', 37, 0.0, 2021, 0.0)
# (5054, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Oct', 38, 0.0, 2021, 0.0)
# (5055, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Oct', 39, 0.0, 2021, 0.0)
# (5056, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Oct', 40, 0.0, 2021, 0.0)
# (5057, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Nov', 41, 0.0, 2021, 0.0)
# (5058, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Nov', 42, 0.0, 2021, 0.0)
# (5059, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Nov', 43, 0.0, 2021, 0.0)
# (5060, 'Honeymoon Island', 'Yellow-rumped Warbler', 'Nov', 44, 0.0, 2021, 0.0)
# (5061, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jan', 1, 10.0, 2021, 0.0)
# (5062, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jan', 2, 5.0, 2021, 0.0)
# (5063, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jan', 3, 12.0, 2021, 0.1666667)
# (5064, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jan', 4, 11.0, 2021, 0.0)
# (5065, 'Honeymoon Island', 'Yellow-throated Warbler', 'Feb', 5, 11.0, 2021, 0.1818182)
# (5066, 'Honeymoon Island', 'Yellow-throated Warbler', 'Feb', 6, 0.0, 2021, 0.0)
# (5067, 'Honeymoon Island', 'Yellow-throated Warbler', 'Feb', 7, 0.0, 2021, 0.0)
# (5068, 'Honeymoon Island', 'Yellow-throated Warbler', 'Feb', 8, 0.0, 2021, 0.0)
# (5069, 'Honeymoon Island', 'Yellow-throated Warbler', 'Mar', 9, 0.0, 2021, 0.0)
# (5070, 'Honeymoon Island', 'Yellow-throated Warbler', 'Mar', 10, 0.0, 2021, 0.0)
# (5071, 'Honeymoon Island', 'Yellow-throated Warbler', 'Mar', 11, 0.0, 2021, 0.0)
# (5072, 'Honeymoon Island', 'Yellow-throated Warbler', 'Mar', 12, 0.0, 2021, 0.0)
# (5073, 'Honeymoon Island', 'Yellow-throated Warbler', 'Apr', 13, 0.0, 2021, 0.0)
# (5074, 'Honeymoon Island', 'Yellow-throated Warbler', 'Apr', 14, 0.0, 2021, 0.0)
# (5075, 'Honeymoon Island', 'Yellow-throated Warbler', 'Apr', 15, 0.0, 2021, 0.0)
# (5076, 'Honeymoon Island', 'Yellow-throated Warbler', 'Apr', 16, 0.0, 2021, 0.0)
# (5077, 'Honeymoon Island', 'Yellow-throated Warbler', 'May', 17, 0.0, 2021, 0.0)
# (5078, 'Honeymoon Island', 'Yellow-throated Warbler', 'May', 18, 0.0, 2021, 0.0)
# (5079, 'Honeymoon Island', 'Yellow-throated Warbler', 'May', 19, 0.0, 2021, 0.0)
# (5080, 'Honeymoon Island', 'Yellow-throated Warbler', 'May', 20, 0.0, 2021, 0.0)
# (5081, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jun', 21, 0.0, 2021, 0.0)
# (5082, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jun', 22, 0.0, 2021, 0.0)
# (5083, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jun', 23, 0.0, 2021, 0.0)
# (5084, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jun', 24, 0.0, 2021, 0.0)
# (5085, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jul', 25, 0.0, 2021, 0.0)
# (5086, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jul', 26, 0.0, 2021, 0.0)
# (5087, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jul', 27, 0.0, 2021, 0.0)
# (5088, 'Honeymoon Island', 'Yellow-throated Warbler', 'Jul', 28, 0.0, 2021, 0.0)
# (5089, 'Honeymoon Island', 'Yellow-throated Warbler', 'Aug', 29, 0.0, 2021, 0.0)
# (5090, 'Honeymoon Island', 'Yellow-throated Warbler', 'Aug', 30, 0.0, 2021, 0.0)
# (5091, 'Honeymoon Island', 'Yellow-throated Warbler', 'Aug', 31, 0.0, 2021, 0.0)
# (5092, 'Honeymoon Island', 'Yellow-throated Warbler', 'Aug', 32, 0.0, 2021, 0.0)
# (5093, 'Honeymoon Island', 'Yellow-throated Warbler', 'Sep', 33, 0.0, 2021, 0.0)
# (5094, 'Honeymoon Island', 'Yellow-throated Warbler', 'Sep', 34, 0.0, 2021, 0.0)
# (5095, 'Honeymoon Island', 'Yellow-throated Warbler', 'Sep', 35, 0.0, 2021, 0.0)
# (5096, 'Honeymoon Island', 'Yellow-throated Warbler', 'Sep', 36, 0.0, 2021, 0.0)
# (5097, 'Honeymoon Island', 'Yellow-throated Warbler', 'Oct', 37, 0.0, 2021, 0.0)
# (5098, 'Honeymoon Island', 'Yellow-throated Warbler', 'Oct', 38, 0.0, 2021, 0.0)
# (5099, 'Honeymoon Island', 'Yellow-throated Warbler', 'Oct', 39, 0.0, 2021, 0.0)
# (5100, 'Honeymoon Island', 'Yellow-throated Warbler', 'Oct', 40, 0.0, 2021, 0.0)
# (5101, 'Honeymoon Island', 'Yellow-throated Warbler', 'Nov', 41, 0.0, 2021, 0.0)
# (5102, 'Honeymoon Island', 'Yellow-throated Warbler', 'Nov', 42, 0.0, 2021, 0.0)
# (5103, 'Honeymoon Island', 'Yellow-throated Warbler', 'Nov', 43, 0.0, 2021, 0.0)
# (5104, 'Honeymoon Island', 'Yellow-throated Warbler', 'Nov', 44, 0.0, 2021, 0.0)
# (5105, 'Honeymoon Island', 'Prairie Warbler', 'Jan', 1, 10.0, 2021, 0.3)
# (5106, 'Honeymoon Island', 'Prairie Warbler', 'Jan', 2, 5.0, 2021, 0.0)
# (5107, 'Honeymoon Island', 'Prairie Warbler', 'Jan', 3, 12.0, 2021, 0.3333333)
# (5108, 'Honeymoon Island', 'Prairie Warbler', 'Jan', 4, 11.0, 2021, 0.1818182)
# (5109, 'Honeymoon Island', 'Prairie Warbler', 'Feb', 5, 11.0, 2021, 0.2727273)
# (5110, 'Honeymoon Island', 'Prairie Warbler', 'Feb', 6, 0.0, 2021, 0.0)
# (5111, 'Honeymoon Island', 'Prairie Warbler', 'Feb', 7, 0.0, 2021, 0.0)
# (5112, 'Honeymoon Island', 'Prairie Warbler', 'Feb', 8, 0.0, 2021, 0.0)
# (5113, 'Honeymoon Island', 'Prairie Warbler', 'Mar', 9, 0.0, 2021, 0.0)
# (5114, 'Honeymoon Island', 'Prairie Warbler', 'Mar', 10, 0.0, 2021, 0.0)
# (5115, 'Honeymoon Island', 'Prairie Warbler', 'Mar', 11, 0.0, 2021, 0.0)
# (5116, 'Honeymoon Island', 'Prairie Warbler', 'Mar', 12, 0.0, 2021, 0.0)
# (5117, 'Honeymoon Island', 'Prairie Warbler', 'Apr', 13, 0.0, 2021, 0.0)
# (5118, 'Honeymoon Island', 'Prairie Warbler', 'Apr', 14, 0.0, 2021, 0.0)
# (5119, 'Honeymoon Island', 'Prairie Warbler', 'Apr', 15, 0.0, 2021, 0.0)
# (5120, 'Honeymoon Island', 'Prairie Warbler', 'Apr', 16, 0.0, 2021, 0.0)
# (5121, 'Honeymoon Island', 'Prairie Warbler', 'May', 17, 0.0, 2021, 0.0)
# (5122, 'Honeymoon Island', 'Prairie Warbler', 'May', 18, 0.0, 2021, 0.0)
# (5123, 'Honeymoon Island', 'Prairie Warbler', 'May', 19, 0.0, 2021, 0.0)
# (5124, 'Honeymoon Island', 'Prairie Warbler', 'May', 20, 0.0, 2021, 0.0)
# (5125, 'Honeymoon Island', 'Prairie Warbler', 'Jun', 21, 0.0, 2021, 0.0)
# (5126, 'Honeymoon Island', 'Prairie Warbler', 'Jun', 22, 0.0, 2021, 0.0)
# (5127, 'Honeymoon Island', 'Prairie Warbler', 'Jun', 23, 0.0, 2021, 0.0)
# (5128, 'Honeymoon Island', 'Prairie Warbler', 'Jun', 24, 0.0, 2021, 0.0)
# (5129, 'Honeymoon Island', 'Prairie Warbler', 'Jul', 25, 0.0, 2021, 0.0)
# (5130, 'Honeymoon Island', 'Prairie Warbler', 'Jul', 26, 0.0, 2021, 0.0)
# (5131, 'Honeymoon Island', 'Prairie Warbler', 'Jul', 27, 0.0, 2021, 0.0)
# (5132, 'Honeymoon Island', 'Prairie Warbler', 'Jul', 28, 0.0, 2021, 0.0)
# (5133, 'Honeymoon Island', 'Prairie Warbler', 'Aug', 29, 0.0, 2021, 0.0)
# (5134, 'Honeymoon Island', 'Prairie Warbler', 'Aug', 30, 0.0, 2021, 0.0)
# (5135, 'Honeymoon Island', 'Prairie Warbler', 'Aug', 31, 0.0, 2021, 0.0)
# (5136, 'Honeymoon Island', 'Prairie Warbler', 'Aug', 32, 0.0, 2021, 0.0)
# (5137, 'Honeymoon Island', 'Prairie Warbler', 'Sep', 33, 0.0, 2021, 0.0)
# (5138, 'Honeymoon Island', 'Prairie Warbler', 'Sep', 34, 0.0, 2021, 0.0)
# (5139, 'Honeymoon Island', 'Prairie Warbler', 'Sep', 35, 0.0, 2021, 0.0)
# (5140, 'Honeymoon Island', 'Prairie Warbler', 'Sep', 36, 0.0, 2021, 0.0)
# (5141, 'Honeymoon Island', 'Prairie Warbler', 'Oct', 37, 0.0, 2021, 0.0)
# (5142, 'Honeymoon Island', 'Prairie Warbler', 'Oct', 38, 0.0, 2021, 0.0)
# (5143, 'Honeymoon Island', 'Prairie Warbler', 'Oct', 39, 0.0, 2021, 0.0)
# (5144, 'Honeymoon Island', 'Prairie Warbler', 'Oct', 40, 0.0, 2021, 0.0)
# (5145, 'Honeymoon Island', 'Prairie Warbler', 'Nov', 41, 0.0, 2021, 0.0)
# (5146, 'Honeymoon Island', 'Prairie Warbler', 'Nov', 42, 0.0, 2021, 0.0)
# (5147, 'Honeymoon Island', 'Prairie Warbler', 'Nov', 43, 0.0, 2021, 0.0)
# (5148, 'Honeymoon Island', 'Prairie Warbler', 'Nov', 44, 0.0, 2021, 0.0)
# (5149, 'Honeymoon Island', 'Northern Cardinal', 'Jan', 1, 10.0, 2021, 0.5)
# (5150, 'Honeymoon Island', 'Northern Cardinal', 'Jan', 2, 5.0, 2021, 1.0)
# (5151, 'Honeymoon Island', 'Northern Cardinal', 'Jan', 3, 12.0, 2021, 0.25)
# (5152, 'Honeymoon Island', 'Northern Cardinal', 'Jan', 4, 11.0, 2021, 0.4545455)
# (5153, 'Honeymoon Island', 'Northern Cardinal', 'Feb', 5, 11.0, 2021, 0.5454545)
# (5154, 'Honeymoon Island', 'Northern Cardinal', 'Feb', 6, 0.0, 2021, 0.0)
# (5155, 'Honeymoon Island', 'Northern Cardinal', 'Feb', 7, 0.0, 2021, 0.0)
# (5156, 'Honeymoon Island', 'Northern Cardinal', 'Feb', 8, 0.0, 2021, 0.0)
# (5157, 'Honeymoon Island', 'Northern Cardinal', 'Mar', 9, 0.0, 2021, 0.0)
# (5158, 'Honeymoon Island', 'Northern Cardinal', 'Mar', 10, 0.0, 2021, 0.0)
# (5159, 'Honeymoon Island', 'Northern Cardinal', 'Mar', 11, 0.0, 2021, 0.0)
# (5160, 'Honeymoon Island', 'Northern Cardinal', 'Mar', 12, 0.0, 2021, 0.0)
# (5161, 'Honeymoon Island', 'Northern Cardinal', 'Apr', 13, 0.0, 2021, 0.0)
# (5162, 'Honeymoon Island', 'Northern Cardinal', 'Apr', 14, 0.0, 2021, 0.0)
# (5163, 'Honeymoon Island', 'Northern Cardinal', 'Apr', 15, 0.0, 2021, 0.0)
# (5164, 'Honeymoon Island', 'Northern Cardinal', 'Apr', 16, 0.0, 2021, 0.0)
# (5165, 'Honeymoon Island', 'Northern Cardinal', 'May', 17, 0.0, 2021, 0.0)
# (5166, 'Honeymoon Island', 'Northern Cardinal', 'May', 18, 0.0, 2021, 0.0)
# (5167, 'Honeymoon Island', 'Northern Cardinal', 'May', 19, 0.0, 2021, 0.0)
# (5168, 'Honeymoon Island', 'Northern Cardinal', 'May', 20, 0.0, 2021, 0.0)
# (5169, 'Honeymoon Island', 'Northern Cardinal', 'Jun', 21, 0.0, 2021, 0.0)
# (5170, 'Honeymoon Island', 'Northern Cardinal', 'Jun', 22, 0.0, 2021, 0.0)
# (5171, 'Honeymoon Island', 'Northern Cardinal', 'Jun', 23, 0.0, 2021, 0.0)
# (5172, 'Honeymoon Island', 'Northern Cardinal', 'Jun', 24, 0.0, 2021, 0.0)
# (5173, 'Honeymoon Island', 'Northern Cardinal', 'Jul', 25, 0.0, 2021, 0.0)
# (5174, 'Honeymoon Island', 'Northern Cardinal', 'Jul', 26, 0.0, 2021, 0.0)
# (5175, 'Honeymoon Island', 'Northern Cardinal', 'Jul', 27, 0.0, 2021, 0.0)
# (5176, 'Honeymoon Island', 'Northern Cardinal', 'Jul', 28, 0.0, 2021, 0.0)
# (5177, 'Honeymoon Island', 'Northern Cardinal', 'Aug', 29, 0.0, 2021, 0.0)
# (5178, 'Honeymoon Island', 'Northern Cardinal', 'Aug', 30, 0.0, 2021, 0.0)
# (5179, 'Honeymoon Island', 'Northern Cardinal', 'Aug', 31, 0.0, 2021, 0.0)
# (5180, 'Honeymoon Island', 'Northern Cardinal', 'Aug', 32, 0.0, 2021, 0.0)
# (5181, 'Honeymoon Island', 'Northern Cardinal', 'Sep', 33, 0.0, 2021, 0.0)
# (5182, 'Honeymoon Island', 'Northern Cardinal', 'Sep', 34, 0.0, 2021, 0.0)
# (5183, 'Honeymoon Island', 'Northern Cardinal', 'Sep', 35, 0.0, 2021, 0.0)
# (5184, 'Honeymoon Island', 'Northern Cardinal', 'Sep', 36, 0.0, 2021, 0.0)
# (5185, 'Honeymoon Island', 'Northern Cardinal', 'Oct', 37, 0.0, 2021, 0.0)
# (5186, 'Honeymoon Island', 'Northern Cardinal', 'Oct', 38, 0.0, 2021, 0.0)
# (5187, 'Honeymoon Island', 'Northern Cardinal', 'Oct', 39, 0.0, 2021, 0.0)
# (5188, 'Honeymoon Island', 'Northern Cardinal', 'Oct', 40, 0.0, 2021, 0.0)
# (5189, 'Honeymoon Island', 'Northern Cardinal', 'Nov', 41, 0.0, 2021, 0.0)
# (5190, 'Honeymoon Island', 'Northern Cardinal', 'Nov', 42, 0.0, 2021, 0.0)
# (5191, 'Honeymoon Island', 'Northern Cardinal', 'Nov', 43, 0.0, 2021, 0.0)
# (5192, 'Honeymoon Island', 'Northern Cardinal', 'Nov', 44, 0.0, 2021, 0.0)
