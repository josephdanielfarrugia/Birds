# %% [markdown]
# ### Parse Data and save it in Dictionary sList

# %%
def retrievemonths():
    months = [] 

    with open("./data/Honeymoon Island.txt", 'r') as f:
        (f.readline())  
   # print(lines)
    # burn the header row
        txt_text =""
        for line in f.readlines()[1:15:]: 
      #  print(line)
            tokens = line.strip().split('\t')   # tokenize the row based on spaces
       
            if (len(tokens) < 15):
                continue
            
       ###  parsing file
            birdname= tokens[0]
            s1 = tokens[1]
            s2 = tokens[2]
            s3 = tokens[3]
            s4 = tokens[4]
            s5 = tokens[5]
            s6 = tokens[6]
            s7 = tokens[7]
            s8 = tokens[8]
            s9 = tokens[9]
            s10= tokens[10]
            s11 = tokens[11]
            s12 = tokens[12]
        
            s13 = tokens[13]
            s14 = tokens[14]
  
            months.append(birdname)
            months.append(s4)
            months.append(s8)
            months.append(s12)
        
            samplelist= []
            samplelist.append(s1)
            samplelist.append(s2)
            samplelist.append(s3)
            samplelist.append(s4)
            samplelist.append(s5)
            samplelist.append(s6)
            samplelist.append(s7)
            samplelist.append(s8)
            samplelist.append(s9)
            samplelist.append(s10)
            samplelist.append(s11)
            samplelist.append(s12)
            samplelist.append(s13)
            samplelist.append(s14)
    f.close()    
    months.pop()
    months.pop()
    months.pop()
    months.pop()
    return months, samplelist
retrievemonths();

# %%
def parsedata():
    s={}
    slist = [] 
    listahadra = [] 
    with open("./data/Honeymoon Island.txt", 'r') as f:
        (f.readline())  
    
   # print(lines)
    # burn the header row
        txt_text =""
        for line in f.readlines()[15:]:
       
           # print(line)
            tokens = line.strip().split('\t')   # tokenize the row based on spaces
       
            if (len(tokens) < 15):
                continue
        
       ###  parsing file
            birdname= tokens[0]
            
            s1 = tokens[1]
            s2 = tokens[2]
            s3 = tokens[3]
            s4 = tokens[4]
            s5 = tokens[5]
            s6 = tokens[6]
            s7 = tokens[7]
            s8 = tokens[8]
            s9 = tokens[9]
            s10= tokens[10]
            s11 = tokens[11]
            s12 = tokens[12]
        
            s13 = tokens[13]
            s14 = tokens[14]
        
           
            s ={}
      
            s["birdname"] = birdname
            s["s1"] =s1
            s["s2"] = s2
            s["s3"] = s3
            s["s4"] = s4
            s["s5"] = s5
            s["s6"] =s6
            s["s7"] = s7
      #  s["img"] = imgname
      #  print(filename, client, content_type, slide_number,text)
            s["s8"] = s8
            s["s9"] = s9
            s["s10"] = s10
            s["s11"] = s11
            s["s12"] = s12
            s["s13"] = s13
            s["s14"] = s14
        
            if (len(s) > 0):
                slist.append(s)
            
    return slist
parsedata()[:13];

# %%
parsedata()[0];

# %%
def createlist():
    mylist=[]
    file = "Honeymoon Island"
    #month =slist[0]["birdname"]
    months = retrievemonths()
    a ,samplelist = retrievemonths()
    week = 1

    slist =(parsedata()[0:13])
    printlist =(parsedata()[0:13])

    for j in range(0,13):
        if j == 0:
            mylist= []
            for i in range(0,len(printlist)):
                value = slist[i]["s1"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('1')
                mylist.append(samplelist[0])
                mylist.append('2021')
                mylist.append(value)
        if j == 1:
            for i in range(0,len(printlist)):
                value = slist[i]["s2"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('2')
                mylist.append(samplelist[1])
                mylist.append('2021')
                mylist.append(value)
        if j == 2:
            for i in range(0,len(printlist)):
                value = slist[i]["s3"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('3')
                mylist.append(samplelist[2])
                mylist.append('2021')
                mylist.append(value)
        if j == 3:
            for i in range(0,len(printlist)):
                value = slist[i]["s4"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][0])
                mylist.append('4')
                mylist.append(samplelist[3])
                mylist.append('2021')
                mylist.append(value)
        if j == 4:
            for i in range(0,len(printlist)):
                value = slist[i]["s5"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('5')
                mylist.append(samplelist[4])
                mylist.append('2021')
                mylist.append(value)
        if j == 5:
            for i in range(0,len(printlist)):
                value = slist[i]["s6"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('6')
                mylist.append(samplelist[5])
                mylist.append('2021')
                mylist.append(value)
        if j == 6:
            for i in range(0,len(printlist)):
                value = slist[i]["s7"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('7')
                mylist.append(samplelist[6])
                mylist.append('2021')
                mylist.append(value)
        if j == 7:
            for i in range(0,len(printlist)):
                value = slist[i]["s8"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('8')
                mylist.append(samplelist[7])
                mylist.append('2021')
                mylist.append(value)
        if j == 8:
            for i in range(0,len(printlist)):
                value = slist[i]["s9"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][1])
                mylist.append('9')
                mylist.append(samplelist[8])
                mylist.append('2021')
                mylist.append(value)
        if j == 9:
            for i in range(0,len(printlist)):
                value = slist[i]["s10"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('10')
                mylist.append(samplelist[9])
                mylist.append('2021')
                mylist.append(value)
        if j == 10:
            for i in range(0,len(printlist)):
                value = slist[i]["s11"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('11')
                mylist.append(samplelist[10])
                mylist.append('2021')
                mylist.append(value)
        if j == 11:
            for i in range(0,len(printlist)):
                value = slist[i]["s12"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('12')
                mylist.append(samplelist[11])
                mylist.append('2021')
                mylist.append(value)
        if j == 12:
            for i in range(0,len(printlist)):
                value = slist[i]["s13"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('13')
                mylist.append(samplelist[12])
                mylist.append('2021')
                mylist.append(value)
        if j == 13:
            for i in range(0,len(printlist)):
                value = slist[i]["s14"]
                mylist.append(file)
                b = slist[i] ["birdname"]
                mylist.append(b)
                mylist.append(months[0][2])
                mylist.append('14')
                mylist.append(samplelist[13])
                mylist.append('2021')
                mylist.append(value)
    return mylist
a = createlist()
a;

# %%
import json
with open('birds.txt', 'w') as filehandle:
    json.dump(createlist(), filehandle)

# %%
a ,samplelist = retrievemonths()
samplelist[0]
# Out:
# '10.0'

# %%
import sqlite3

def create_table():
    #Connecting to sqlite
    conn = sqlite3.connect('bird.db')


    #Creating a cursor object using the cursor() method
    cursor = conn.cursor()

    #Droping BIRDS table if already exists.
    #cursor.execute("DROP TABLE IF EXISTS Birds")

    #Creating table as per requirement
    sql=''' CREATE TABLE IF NOT EXISTS Birds 
        (id integer PRIMARY KEY NOT NULL ,
         Location text NOT NULL, 
         BirdName text NOT NULL,
         Month text NOT NULL, 
         Week integer not null, 
         Sample integer not null, 
         Year integer NOT NULL, 
         Value integer NOT null)'''
    cursor.execute(sql)
    print("Table created successfully........")

    # Commit your changes in the database
    conn.commit()

    #Closing the connection
    conn.close()
create_table()
# Out:
# Table created successfully........

# %%
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    conn = sqlite3.connect('bird.db')
    cur = conn.cursor()
    cur.execute("SELECT * FROM Birds")

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
select_all_tasks(conn)
# Out:
# (1, 'Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', 1, 10, 2021, 0.1)
# (2, 'Black-bellied Whistling-Duck', 'Jan', '1', 10, 2021, 0.1, 'Honeymoon Island')
# (3, 'Jan', '1', '10.0', 2021, 0.1, 'Honeymoon Island', 'Blue-winged Teal')
# (4, '1', '10.0', '2021', 0.1, 'Honeymoon Island', 'Blue-winged Teal', 'Jan')
# (5, '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1)
# (6, '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10)
# (7, '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10, 2021)
# (8, 'Honeymoon Island', 'Blue-winged Teal', 'Jan', 1, 10, 2021, 0.2)
# (9, 'Blue-winged Teal', 'Jan', '1', 10, 2021, 0.2, 'Honeymoon Island')
# (10, 'Jan', '1', '10.0', 2021, 0.2, 'Honeymoon Island', 'Redhead')
# (11, '1', '10.0', '2021', 0.2, 'Honeymoon Island', 'Redhead', 'Jan')
# (12, '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', 1)
# (13, '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', 1, 10)

# %% [markdown]
# # SQL NOT ENTERED CORRECTLY IN DATABASE

# %%
def create_task():
    """
    Create a new task
    :param conn:
    :param task:
    :return:
    """
  
    conn = sqlite3.connect(r"./data/bird.db")
    cur = conn.cursor()
    
    for i in range((len(createlist()[:13]))):
        task = (createlist()[i:][0], createlist()[i:][1], createlist()[i:][2], createlist()[i:][3], createlist()[i:][4], createlist()[i:][5],createlist()[i:][6])
       # task = createlist()[i:][0]
        sql = ''' INSERT INTO BIRDS(Location, BirdName, Month,Week,Sample, Year, Value) VALUES(?,?,?,?,?,?,?)'''  
        cur = conn.cursor()
        cur.execute(sql,task)
        print(task)
        conn.commit()
    return cur.lastrowid
    #return sql

#for i in range(len(createlist())-7):
 #   task_1 = (createlist()[i:][0], createlist()[i:][1], createlist()[i:][2], createlist()[i:][3], createlist()[i:][4], createlist()[i:][5],createlist()[i:][6])
   # print(task_1)
create_task()
# Out:
# ('Honeymoon Island', 'Black-bellied Whistling-Duck', 'Jan', '1', '10.0', '2021', '0.1')
# ('Black-bellied Whistling-Duck', 'Jan', '1', '10.0', '2021', '0.1', 'Honeymoon Island')
# ('Jan', '1', '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal')
# ('1', '10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan')
# ('10.0', '2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1')
# ('2021', '0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0')
# ('0.1', 'Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0', '2021')
# ('Honeymoon Island', 'Blue-winged Teal', 'Jan', '1', '10.0', '2021', '0.2')
# ('Blue-winged Teal', 'Jan', '1', '10.0', '2021', '0.2', 'Honeymoon Island')
# ('Jan', '1', '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead')
# ('1', '10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan')
# ('10.0', '2021', '0.2', 'Honeymoon Island', 'Redhead', 'Jan', '1')
# ...

# %% [markdown]
# # THIS SHOULD BE THE SAME AS WRITTEN IN DB!!!

# %%
createlist()
# Out:
# ['Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.2',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.3',
#  'Honeymoon Island',
#  'Lesser Scaup',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Bufflehead',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Red-breasted Merganser',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.4',
#  'Honeymoon Island',
#  'Pied-billed Grebe',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
#  'Horned Grebe',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Rock Pigeon',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.1',
#  'Honeymoon Island',
#  'Eurasian Collared-Dove',
#  'Jan',
#  '1',
#  '10.0',
#  '2021',
#  '0.0',
#  'Honeymoon Island',
# ...
