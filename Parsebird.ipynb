# %% [markdown]
# ### Parse Data and save it in Dictionary sList

# %%
d ={}
s={}
slist = [] 
dlist = []
mynum =[]
count =0
lst_slide_no = -1
with open("./data/Honeymoon Island.txt", 'r') as f:
    (f.readline())  
    
   # print(lines)
    # burn the header row
    txt_text =""
    for line in f:
       
      #  print(line)
        tokens = line.strip().split('\t')   # tokenize the row based on spaces
       
        if (len(tokens) < 15):
            continue
        
       ###  parsing file
        birdname= tokens[0]
        s1 = tokens[1]
        s2 = tokens[2]
        s3 = tokens[3]
        s4 = tokens[4]
        s5 = tokens[5]
        s6 = tokens[6]
        s7 = tokens[7]
        s8 = tokens[8]
        s9 = tokens[9]
        s10= tokens[10]
        s11 = tokens[11]
        s12 = tokens[12]
        
        s13 = tokens[13]
        s14 = tokens[14]
        
        
       
        s = {}   
      
      
        s["birdname"] = birdname
        s["s1"] =s1
        s["s2"] = s2
        s["s3"] = s3
        s["s4"] = s4
        s["s5"] = s5
        s["s6"] =s6
        s["s7"] = s7
      #  s["img"] = imgname
      #  print(filename, client, content_type, slide_number,text)
        s["s8"] = s8
        s["s9"] = s9
        s["s10"] = s10
        s["s11"] = s11
        s["s12"] = s12
        s["s13"] = s13
        s["s14"] = s14
        
        if (len(s) > 0):
            slist.append(s)
        
slist[:4]
# Out:
# [{'birdname': 'Jan',
#   's1': '',
#   's2': '',
#   's3': '',
#   's4': 'Feb',
#   's5': '',
#   's6': '',
#   's7': '',
#   's8': 'Mar',
#   's9': '',
#   's10': '',
#   's11': '',
#   's12': 'Apr',
#   's13': '',
#   's14': ''},
#  {'birdname': 'Sample Size:',
#   's1': '10.0',
#   's2': '5.0',
#   's3': '12.0',
#   's4': '11.0',
#   's5': '11.0',
#   's6': '0.0',
#   's7': '0.0',
#   's8': '0.0',
#   's9': '0.0',
#   's10': '0.0',
#   's11': '0.0',
#   's12': '0.0',
#   's13': '0.0',
#   's14': '0.0'},
#  {'birdname': 'Black-bellied Whistling-Duck',
#   's1': '0.1',
#   's2': '1.0',
#   's3': '0.0',
#   's4': '0.0',
#   's5': '0.0',
#   's6': '0.0',
#   's7': '0.0',
#   's8': '0.0',
#   's9': '0.0',
#   's10': '0.0',
#   's11': '0.0',
#   's12': '0.0',
#   's13': '0.0',
#   's14': '0.0'},
#  {'birdname': 'Blue-winged Teal',
#   's1': '0.2',
#   's2': '2.0',
#   's3': '0.0',
#   's4': '0.0',
#   's5': '0.0909091',
#   's6': '0.0',
#   's7': '0.0',
#   's8': '0.0',
#   's9': '0.0',
#   's10': '0.0',
#   's11': '0.0',
#   's12': '0.0',
#   's13': '0.0',
#   's14': '0.0'}]

# %%
mylist=[]
file = "Honeymoon Island"
month =slist[0]["birdname"]
week = 1
sample = slist[1]["s1"]
s2 = slist[1]["s2"]

printlist =(slist[0:5])

for j in range(0,2):
    if j == 0:
       for i in range(2,len(printlist)):
            mylist.append(file)
            b = slist[i] ["birdname"]
            mylist.append(b)
            mylist.append(month)
            mylist.append(week)
            mylist.append(sample)
            value = slist[i]["s1"]
            mylist.append(value)
    if j == 1:
        for i in range(2,len(printlist)):
            value = slist[i]["s2"]
            mylist.append(file)
            b = slist[i] ["birdname"]
            mylist.append(b)
            mylist.append(month)
            mylist.append(week)
            mylist.append(s2)
            mylist.append(value)
        
        
mylist
# Out:
# ['Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  1,
#  '10.0',
#  '0.1',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  1,
#  '10.0',
#  '0.2',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  1,
#  '10.0',
#  '0.3',
#  'Honeymoon Island',
#  'Black-bellied Whistling-Duck',
#  'Jan',
#  1,
#  '5.0',
#  '1.0',
#  'Honeymoon Island',
#  'Blue-winged Teal',
#  'Jan',
#  1,
#  '5.0',
#  '2.0',
#  'Honeymoon Island',
#  'Redhead',
#  'Jan',
#  1,
#  '5.0',
#  '3.0']
